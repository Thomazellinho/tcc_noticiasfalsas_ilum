# %%
# Importações

import nltk

from sklearn import svm
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    cohen_kappa_score,
    roc_auc_score,
    confusion_matrix
)

import pandas as pd
import numpy as np

from nltk.corpus import stopwords

import re

# Cross validate

from sklearn.model_selection import cross_validate, cross_val_score

# Modelos

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

import matplotlib.pyplot as plt

# %%
# Importação do Dataframe contendo títulos de notícias relacionadas a saúde.

dataframe = pd.read_csv('dados/combined_df.zip')

display(dataframe)
# Out:
#                                                   title  \
# 0     Ministro alemão quer disponibilizar testes cov...
# 1     'Minions 2' ganha nova data 2021 após adiament...
# 2     Atividade física interfere prognóstico casos g...
# 3     Pesquisa brasileira usou doses letais matar pa...
# 4     Álcool gel, luvas máscaras roubados posto saúd...
# ...                                                 ...
# 5119  monitoramento eventosacesse monitoramento even...
# 5120  SP anuncia relaxamento isolamento 11 maio, omi...
# 5121  vídeo vítimas covid descendo amarrados necroté...
# 5122  Termômetro digital testa lança raio destruidor...
# 5123  Revisão estudo publicado site MS garante eficá...
#
#                                                    link                 date  \
# 0     https://g1.globo.com/mundo/noticia/2020/07/05/...    05/07/2020 08h51
# 1     https://entretenimento.uol.com.br/noticias/red...    01/04/2020 14h20
# 2     https://www.uol.com.br/vivabem/noticias/redaca...    26/01/2021 09h13
# 3     https://projetocomprova.com.br/publicações/pes...           2020/04/24
# 4     https://noticias.uol.com.br/saude/ultimas-noti...    17/03/2020 21h03
# ...                                                 ...                  ...
# 5119  https://www.gov.br/saude/pt-br/vacinacao/esavi...  Data não disponível
# 5120  https://noticias.uol.com.br/videos/2020/04/22/...    22/04/2020 14h54
# 5121  http://www.e-farsas.com/o-video-de-vitimas-do-...  Data não disponível
# 5122  https://www.boatos.org/saude/termometro-na-tes...           18/08/2020
# 5123  https://projetocomprova.com.br/publicações/rev...           2021/01/19
#
#                   Site  noticia_falsa  \
# 0                  NaN              1
# 1                  NaN              1
# 2                  NaN              1
# 3                  NaN              0
# 4                  NaN              1
# ...                ...            ...
# 5119      gov.br saude              1
# 5120               NaN              1
# 5121  E-Farsas (Falso)              0
# 5122               NaN              0
# 5123               NaN              0
#
#                                             corpo_texto
# 0     o ministrar interior alemanha horst seehofer o...
# 1     minions o origem gru datar chegar o cinema o u...
# 2     estudo recente sugerir o prático regular exerc...
# 3     publicação rede social pesquisar brasileiro ac...
# 4     postar saudar goiânia bairro conjuntar vero cr...
# ...                                                 ...
# 5119  ['monitoramento', 'eventos', 'ministério', 'sa...
# 5120  patrício ellen secretário desenvolvimento econ...
# 5121  ['vídeo', 'vítimas', 'covid', 'descendo', 'ama...
# 5122  “ raiar testo destruidor glândula pineal cuida...
# 5123  o artigo falir o hidroxicloroquina tratamento ...
#
# [5124 rows x 6 columns]

# %%
# Cria dataframe para processamento
df = dataframe.copy()
df_sorted = df.sort_values(by='noticia_falsa').reset_index(drop=True)

# Transformar a coluna título em string
df_sorted['title'] = df_sorted['title'].astype(str)

# %%
### Filtrando notícias com valores 0 e 1
noticias_falsa_0 = df_sorted[df_sorted['noticia_falsa'] == 0]
noticias_falsa_1 = df_sorted[df_sorted['noticia_falsa'] == 1] # Aqui estão representadas as notícias verdadeiras

### Selecionar, aleatoriamente, 1000 notícias com valores 0 e 1500 com valores 1
amostra_0 = noticias_falsa_0.sample(n=1000, random_state=42)
amostra_1 = noticias_falsa_1.sample(n=1500, random_state=42)

# Criando um novo dataframe com estas notícias
novo_df = pd.concat([amostra_0, amostra_1])

# Resetando o index
novo_df = novo_df.sample(frac=1, random_state=24).reset_index(drop=True)

display(novo_df)
# Out:
#                                                   title  \
# 0     #BoasNotícias30/3: Cidade imune, toneladas fei...
# 1                                                gov.br
# 2     sistema saúde pública segue filosofia medicina...
# 3                   portaria nº 2.992, 26 dezembro 2012
# 4     Serrana (SP) aumento mortes Covid-19 causa vac...
# ...                                                 ...
# 2495  Gabbardo reforça advertência contra cloroquina...
# 2496  Prefeito São Paulo proibiu hidroxicloroquina u...
# 2497  Amapá pode receber 4 profissionais Programa Ma...
# 2498          www.medicospelavidacovid19.com.br/jornada
# 2499  Em Feira Santana, homem parada cardíaca enterr...
#
#                                                    link                 date  \
# 0     https://www.uol.com.br/ecoa/ultimas-noticias/2...    30/03/2020 19h18
# 1     https://www.gov.br/saude/pt-br/vacinacao/esavi...  Data não disponível
# 2     https://medicospelavidacovid19.com.br/opiniao/...  Data não disponível
# 3     https://www.gov.br/saude/pt-br/vacinacao/legis...  Data não disponível
# 4     https://www.boatos.org/saude/serrana-sp-aument...           05/04/2021
# ...                                                 ...                  ...
# 2495  https://noticias.uol.com.br/saude/ultimas-noti...    08/07/2020 14h10
# 2496  https://projetocomprova.com.br/publicações/pre...           2020/06/26
# 2497  https://www.gov.br/saude/pt-br/assuntos/notici...     09/03/2021 19h03
# 2498  https://www.medicospelavidacovid19.com.br/jornada  Data não disponível
# 2499  https://www.boatos.org/saude/feira-de-santana-...                  NaN
#
#                    Site  noticia_falsa  \
# 0                   NaN              1
# 1          gov.br saude              1
# 2     Médicos Pela Vida              0
# 3          gov.br saude              1
# 4                   NaN              0
# ...                 ...            ...
# 2495                NaN              1
# 2496                NaN              0
# 2497                NaN              1
# 2498  Médicos Pela Vida              0
# 2499                NaN              0
#
#                                             corpo_texto
# 0     o discursar o preocupação pessoa sustentar dur...
# 1                         ['erro', 'carregar', 'texto']
# 2     ['sistema', 'saúde', 'pública', 'segue', 'filo...
# 3     ['404', 'not', 'found', 'not', 'found', 'the',...
# 4     cidade serrana-sp escolhido doria e dimas cova...
# ...                                                 ...
# 2495  o centrar contingência coronavírus paulo volta...
# 2496  o o contrário afirmar publicação rede social o...
# 2497  aprimorar o assistência unidade básico saudar ...
# 2498  ['página', 'encontrada', 'mpv', 'skip', 'to', ...
# 2499  feirar santana homem parar cardíaco enterrar v...
#
# [2500 rows x 6 columns]

# %%
# Agora, separaremos uma porção para validação com dados externos

### Separar as notícias restantes
restantes_0 = noticias_falsa_0.drop(amostra_0.index)
restantes_1 = noticias_falsa_1.drop(amostra_1.index)

# Selecionar 449 notícias restantes com valor 0 e 800 com valor 1
amostra_0_restante = restantes_0
amostra_1_restante = restantes_1.sample(n=800, random_state=42)

# Criar um novo dataframe
segundo_df = pd.concat([amostra_0_restante, amostra_1_restante])

# Bagunçar o df
segundo_df = segundo_df.sample(frac=1, random_state=48).reset_index(drop=True)

display(segundo_df)
# Out:
#                                                   title  \
# 0     monitoramento rápido coberturas vacinais pós-c...
# 1     Opas vê risco faltar insumos intubação hospita...
# 2     PF mira fraudes contratos R$ 33,7 mi combate c...
# 3     Ministério Saúde identificou 204 casos novas v...
# 4     Venezuela recebe 73 toneladas ajuda europeia c...
# ...                                                 ...
# 1239  Donos mandam trocar fechaduras igreja após pas...
# 1240  Coronavírus: Polônia eleições presidenciais in...
# 1241                                 ofícios circulares
# 1242  É #FAKE escovas dentes pacientes Covid-19 pode...
# 1243  Portugal supera marca mil mortes provocadas co...
#
#                                                    link  \
# 0     https://www.gov.br/saude/pt-br/vacinacao/publi...
# 1     https://noticias.uol.com.br/ultimas-noticias/a...
# 2     https://noticias.uol.com.br/ultimas-noticias/a...
# 3     https://noticias.uol.com.br/saude/ultimas-noti...
# 4     https://noticias.uol.com.br/ultimas-noticias/a...
# ...                                                 ...
# 1239  https://noticias.uol.com.br/internacional/ulti...
# 1240  https://noticias.uol.com.br/ultimas-noticias/a...
# 1241  https://www.gov.br/saude/pt-br/assuntos/covid-...
# 1242  https://g1.globo.com/fato-ou-fake/coronavirus/...
# 1243  https://noticias.uol.com.br/ultimas-noticias/e...
#
#                                                  date          Site  \
# 0                                 Data não disponível  gov.br saude
# 1     31/03/2021 13h05Atualizada em 31/03/2021 14h00            NaN
# 2                                   12/01/2021 12h48            NaN
# 3                                   23/02/2021 15h59            NaN
# 4                                   22/08/2020 16h11            NaN
# ...                                               ...           ...
# 1239                                07/04/2020 17h13            NaN
# 1240                                06/04/2020 21h09            NaN
# 1241                              Data não disponível  gov.br saude
# 1242                                       03/12/2020           NaN
# 1243                                01/05/2020 19h44            NaN
#
#       noticia_falsa                                        corpo_texto
# 0                 1  ['monitoramento', 'rápido', 'coberturas', 'vac...
# 1                 1  diretora organização pan-americana saudar opar...
# 2                 1  o pf polícia federal piauí deflagrar hoje o op...
# 3                 1  o secretariar vigilância saudar ligar o o mini...
# 4                 1  caracas ago afp o venezuela receber n sábado t...
# ...             ...                                                ...
# 1239              1  pastor cidade lodi califórnio planejar o reali...
# 1240              1  atual pandemia coronavírus o parlamentar polôn...
# 1241              1  ['ofícios', 'circulares', 'ministério', 'saúde...
# 1242              0  circular rede social o escovar dentar o covid-...
# 1243              1  portugal registrar morte n sexta-feira consequ...
#
# [1244 rows x 6 columns]

# %%
# Checar os títulos únicos em cada Dataframe

corpo_texto_novo_df = set(novo_df['corpo_texto'].unique())
corpo_texto_segundo_df = set(segundo_df['corpo_texto'].unique())

# Vendo se há títulos repetidos

corpo_texto_repetidos = corpo_texto_novo_df.intersection(corpo_texto_segundo_df)

print(f"Corpos do texto repetidos: {corpo_texto_repetidos}")

# Remover do 'segundo_df' os títulos repetidos

segundo_df_filtrado = segundo_df[~segundo_df['corpo_texto'].isin(corpo_texto_novo_df)]

segundo_df_filtrado = segundo_df_filtrado.reset_index(drop=True)

display(segundo_df_filtrado)
# Out:
# Corpos do texto repetidos: {"['erro', 'carregar', 'texto']", "['pdf14', '1', '0', 'obj', 'endobj', '3', '0', 'obj', 'endobj', '6', '0', 'obj', 'stream', 'x', 'jaр', 'ej6', 'm쎛me', 'nlm', 'bt', 'bb', 'lt']", "['404', 'not', 'found', 'not', 'found', 'the', 'requested', 'url', 'was', 'not', 'found', 'on', 'this', 'server']", "['ministério', 'saúde', 'ir', 'conteúdo', '1', 'ir', 'página', 'inicial', '2', 'ir', 'menu', 'navegação', '3', 'ir', 'busca', '4', 'ir', 'mapa', 'site', '5', 'atenção', 'navegador', 'pode', 'executar', 'javascript', 'alguns', 'recursos', 'podem', 'funcionar', 'corretamente', 'portal', 'govbr', 'acesso', 'rápido', 'acesso', 'rápido', 'órgãos', 'governo', 'acesso', 'informação', 'legislação', 'acessibilidade', 'pt', 'escolher', 'idioma', 'en', 'es', 'redefinir', 'cookies', 'mudar', 'modo', 'alto', 'contraste', 'abrir', 'menu', 'principal', 'navegação', 'ministério', 'saúde', 'termos', 'buscados', 'assinatura', 'enem', 'imposto', 'renda', 'mei', 'inss', 'termos', 'buscados', 'assinatura', 'enem', 'imposto', 'renda', 'assuntos', 'notícias', '2024', '2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', 'notícias', 'estados', 'acre', 'alagoas', 'amapá', 'amazonas', 'bahia', 'ceará', 'distrito', 'federal', 'espírito', 'santo', 'goiás', 'maranhão', 'mato', 'grosso', 'mato', 'grosso', 'sul', 'minas', 'gerais', 'pará', 'paraíba', 'paraná', 'pernambuco', 'piauí', 'rio', 'janeiro', 'rio', 'grande', 'norte', 'rio', 'grande', 'sul', 'rondônia', 'roraima', 'santa', 'catarina', 'paulo', 'sergipe', 'tocantins', 'saúde', 'z', 'b', 'c', 'd', 'f', 'g', 'h', 'i', 'l', 'm', 'p', 'r', 's', 't', 'u', 'v', 'z', 'brasil', 'saudável', 'balanço', '2023', 'covid19', 'yanomami', 'novo', 'pac', 'saúde', 'onda', 'calor', 'protocolos', 'clínicos', 'diretrizes', 'terapêuticas', 'pcdt', 'retomada', 'obras', 'saúde', 'saúde', 'brasil', 'saúde', 'ciência', 'vacinação', 'calendário', 'vacinação', 'calendário', 'técnico', 'nacional', 'vacinação', 'atividades', 'vacinação', 'alta', 'qualidade', 'distribuição', 'imunobiológicos', 'segurança', 'vacinas', 'vacinas', 'grupos', 'especiais', 'vacinação', 'viajantes', 'rede', 'frio', 'informes', 'técnicos', 'notas', 'técnicas', 'manuais', 'legislação', 'publicações', 'estratégia', 'vacinação', 'contra', 'influenza', 'região', 'norte', '2024', 'cobertura', 'vacinal', 'monitoramento', 'dados', 'vacinação', 'composição', 'organograma', 'secretaria', 'executiva', 'consultoria', 'jurídica', 'denasus', 'atenção', 'especializada', 'saúde', 'atenção', 'primária', 'ciência', 'tecnologia', 'saúde', 'vigilância', 'saúde', 'ambiente', 'trabalho', 'educação', 'saúde', 'saúde', 'indígena', 'saúde', 'digital', 'corregedoria', 'órgãos', 'colegiados', 'conselho', 'nacional', 'saúde', 'conselho', 'saúde', 'suplementar', 'consu', 'comissão', 'nacional', 'incorporação', 'tecnologias', 'sus', 'conitec', 'entidades', 'vinculadas', 'autarquias', 'fundações', 'públicas', 'empresas', 'públicas', 'acesso', 'informação', 'institucional', 'agenda', 'autoridades', 'ações', 'programas', 'carta', 'serviços', 'participação', 'social', 'audiências', 'públicas', 'consultas', 'públicas', 'chamamentos', 'públicos', 'conselhos', 'comitês', 'órgãos', 'colegiados', 'auditorias', 'convênios', 'transferências', 'receitas', 'despesas', 'licitações', 'contratos', 'licitações', 'aquisições', 'internacionais', 'medicamentos', 'iot', 'contratos', 'ascom', 'contratos', 'departamento', 'logística', 'saúde', 'dlog', 'plano', 'contratação', 'anual', 'requisições', 'anestésicos', 'sessões', 'públicas', 'contratos', 'superintendências', 'sems', 'contratos', 'bens', 'serviços', 'administrativos', 'saa', 'servidores', 'avaliação', 'desempenho', 'despesas', 'ações', 'desenvolvimento', 'pessoas', 'estágio', 'informações', 'classificadas', 'serviço', 'informação', 'cidadão', 'sic', 'relatório', 'monitoramento', 'lai', '2024', 'perguntas', 'frequentes', 'faq', 'corregedoria', 'dados', 'abertos', 'sei', 'banco', 'preços', 'concursos', ' ...
#                                                   title  \
# 0     monitoramento rápido coberturas vacinais pós-c...
# 1     Opas vê risco faltar insumos intubação hospita...
# 2     PF mira fraudes contratos R$ 33,7 mi combate c...
# 3     Ministério Saúde identificou 204 casos novas v...
# 4     Venezuela recebe 73 toneladas ajuda europeia c...
# ...                                                 ...
# 1220  Donos mandam trocar fechaduras igreja após pas...
# 1221  Coronavírus: Polônia eleições presidenciais in...
# 1222                                 ofícios circulares
# 1223  É #FAKE escovas dentes pacientes Covid-19 pode...
# 1224  Portugal supera marca mil mortes provocadas co...
#
#                                                    link  \
# 0     https://www.gov.br/saude/pt-br/vacinacao/publi...
# 1     https://noticias.uol.com.br/ultimas-noticias/a...
# 2     https://noticias.uol.com.br/ultimas-noticias/a...
# 3     https://noticias.uol.com.br/saude/ultimas-noti...
# 4     https://noticias.uol.com.br/ultimas-noticias/a...
# ...                                                 ...
# 1220  https://noticias.uol.com.br/internacional/ulti...
# 1221  https://noticias.uol.com.br/ultimas-noticias/a...
# 1222  https://www.gov.br/saude/pt-br/assuntos/covid-...
# 1223  https://g1.globo.com/fato-ou-fake/coronavirus/...
# 1224  https://noticias.uol.com.br/ultimas-noticias/e...
#
#                                                  date          Site  \
# 0                                 Data não disponível  gov.br saude
# 1     31/03/2021 13h05Atualizada em 31/03/2021 14h00            NaN
# 2                                   12/01/2021 12h48            NaN
# 3                                   23/02/2021 15h59            NaN
# 4                                   22/08/2020 16h11            NaN
# ...                                               ...           ...
# 1220                                07/04/2020 17h13            NaN
# 1221                                06/04/2020 21h09            NaN
# 1222                              Data não disponível  gov.br saude
# 1223                                       03/12/2020           NaN
# 1224                                01/05/2020 19h44            NaN
#
#       noticia_falsa                                        corpo_texto
# 0                 1  ['monitoramento', 'rápido', 'coberturas', 'vac...
# 1                 1  diretora organização pan-americana saudar opar...
# 2                 1  o pf polícia federal piauí deflagrar hoje o op...
# 3                 1  o secretariar vigilância saudar ligar o o mini...
# 4                 1  caracas ago afp o venezuela receber n sábado t...
# ...             ...                                                ...
# 1220              1  pastor cidade lodi califórnio planejar o reali...
# 1221              1  atual pandemia coronavírus o parlamentar polôn...
# 1222              1  ['ofícios', 'circulares', 'ministério', 'saúde...
# 1223              0  circular rede social o escovar dentar o covid-...
# 1224              1  portugal registrar morte n sexta-feira consequ...
#
# [1225 rows x 6 columns]

# %%
# Variáveis para padronização/configuração

scores = ['accuracy', 'precision', 'roc_auc']
usar_links = False

# %%
# Checar se há títulos vazios
non_empty_titles = novo_df['corpo_texto'].apply(lambda x: len(x.strip()) > 0)
non_empty_links = novo_df['link'].apply(lambda x: len(x.strip()) > 0)

# Checar o resultado
print(non_empty_titles.head())
print("Há documentos vazios?", not non_empty_titles.all())
print("Há links vazios?", not non_empty_links.all())
print("Número de documentos vazios:", (~non_empty_titles).sum())
print("Número de links vazios:", (~non_empty_links).sum())
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: corpo_texto, dtype: bool
# Há documentos vazios? False
# Há links vazios? False
# Número de documentos vazios: 0
# Número de links vazios: 0

# %%
# Iniciar o processo de TF-IDF
tfidf_vectorizer = TfidfVectorizer()

# Nesta célula, será aplicado o TF-IDF aos títulos das notícias, caso não haja nenhum vazio
temp_tit = novo_df['corpo_texto'].tolist()
if non_empty_titles.all():
    titles_tfidf = tfidf_vectorizer.fit_transform(temp_tit)
    print('TF-IDF aplicado com sucesso.')
    tfidf = titles_tfidf
else:
    print('Há documentos vazios ou apenas stop words.')
# Out:
# TF-IDF aplicado com sucesso.

# %%
def split_and_clean(link):
# Dividir o link por '/', '-', '%', '.', e ':'
    words = re.split(r'[/\-\%\.\:\_]', link)
    # Remover palavras indesejadas, stopwords e letras isoladas, mantendo acentos
    unwanted = {'https', 'www', 'com', 'br', 'pt', 'html', 'htm', 'ghtml', 'php'}
    cleaned_words = [
    word for word in words
    if not any(unwanted_word in word.lower() for unwanted_word in unwanted)
    and len(word) > 1
    ]
    return cleaned_words

if usar_links:

    # Tratando os links
    df['processed_links'] = df['link'].apply(split_and_clean)

    # TF-IDF para os combinação título e link
    temp_link = [' '.join(i) for i in df['processed_links']]
    temp_tit_link = [' '.join(list(a)) for a in zip(temp_tit, temp_link)]
    print(temp_tit_link)
    if non_empty_links.all():
        tit_link_tfidf = tfidf_vectorizer.fit_transform(temp_tit_link)
        print('TF-IDF aplicado com sucesso.')
        tfidf = tit_link_tfidf
    else:
        print('Há items vazios ou apenas stop words.')

# %%
# Criação de vetores
X = tfidf
y = novo_df['noticia_falsa']

corpos_texto = novo_df['corpo_texto'].tolist()

print("Dimensões de X:", X.shape)
print("Dimensões de y:", y.shape)
# Out:
# Dimensões de X: (2500, 29563)
# Dimensões de y: (2500,)

# %%
# Padronizando scores para todos os modelos.

scores = ['accuracy', 'precision', 'roc_auc']

# %% [markdown]
# ### Árvore de Decisão

# %%
# Cria modelo
modelo_ad = DecisionTreeClassifier()
modelo_ad

# Validação cruzada
resultados_ad = cross_validate(modelo_ad, X, y, scoring=scores)

acc_ad = resultados_ad['test_accuracy'].mean()
prec_ad = resultados_ad['test_precision'].mean()
rocauc_ad = resultados_ad['test_roc_auc'].mean()
print(f'Acurácia: {acc_ad:.3f}\nPrecisão: {prec_ad:.3f}\nROC-AUC: {rocauc_ad:.3f}')
# Out:
# Acurácia: 0.860
# Precisão: 0.890
# ROC-AUC: 0.857

# %% [markdown]
# ### Floresta Aleatória

# %%
# Cria modelo
modelo_rf = RandomForestClassifier()
modelo_rf

# Validação cruzada
resultados_rf = cross_validate(modelo_rf, X, y, scoring=scores)

acc_rf = resultados_rf['test_accuracy'].mean()
prec_rf = resultados_rf['test_precision'].mean()
rocauc_rf = resultados_rf['test_roc_auc'].mean()
print(f'Acurácia: {acc_rf:.3f}\nPrecisão: {prec_rf:.3f}\nROC-AUC: {rocauc_rf:.3f}')
# Out:
# Acurácia: 0.936
# Precisão: 0.927
# ROC-AUC: 0.974

# %% [markdown]
# ### Regressão Logística

# %%
# Cria modelo
modelo_lr = LogisticRegression()
modelo_lr

# Validação cruzada
resultados_lr = cross_validate(modelo_lr, X, y, scoring=scores)

acc_lr = resultados_lr['test_accuracy'].mean()
prec_lr = resultados_lr['test_precision'].mean()
rocauc_lr = resultados_lr['test_roc_auc'].mean()
print(f'Acurácia: {acc_lr:.3f}\nPrecisão: {prec_lr:.3f}\nROC-AUC: {rocauc_lr:.3f}')
# Out:
# Acurácia: 0.921
# Precisão: 0.901
# ROC-AUC: 0.974

# %% [markdown]
# ### SVC

# %%
# Parâmetros
C = 77
kernel = 'rbf'
gamma = 0.01

# Cria modelo
modelo_svm = svm.SVC(C=C, kernel=kernel, gamma=gamma)

# Validação cruzada
resultados_svm = cross_validate(modelo_svm, X, y, scoring=scores)

acc_svm = resultados_svm['test_accuracy'].mean()
prec_svm = resultados_svm['test_precision'].mean()
rocauc_svm = resultados_svm['test_roc_auc'].mean()
print(f'Acurácia: {acc_svm:.3f}\nPrecisão: {prec_svm:.3f}\nROC-AUC: {rocauc_svm:.3f}')
# Out:
# Acurácia: 0.941
# Precisão: 0.940
# ROC-AUC: 0.979

# %% [markdown]
# ### Função de comparação

# %%
stop_words = set(stopwords.words('portuguese'))

def trata_padrao(titulo, usar_links=False, link=None):
    '''
    Função para padronizar o tratamento dos títulos.

    Args:
    titulo (str) = título da notícia
    usar_links (bool) = usar ou não o link
    link (str) = link da notícia
    '''

    # Pré-processamento do titulo

    titulo = str(titulo).lower()
    titulo = nltk.word_tokenize(titulo)
    titulo = [word for word in titulo if word not in stop_words]
    titulo = [' '.join(titulo)]
    temp_tit = titulo

    # se usar link, pre processar link
    if usar_links:
        link = [split_and_clean(link)]
        temp_link = [' '.join(i) for i in link]
        print(temp_tit,temp_link)
        temp_tit_link = [' '.join(list(a)) for a in zip(temp_tit, temp_link)]
        processed = temp_tit_link
    else:
        processed = titulo

    return processed

# %%
# Define modelos para teste
modelos = [modelo_ad, modelo_rf, modelo_lr, modelo_svm]

# Treina modelos com todos os dados
for modelo in modelos:
    modelo.fit(X, y)

# Função para predizer novos títulos
def predict_title(titulo):
    preprocessed_title = trata_padrao(titulo)

    tfidf_vector = tfidf_vectorizer.transform(preprocessed_title)
    preds = dict()

    for modelo in modelos:
        preds[modelo] = modelo.predict(tfidf_vector)

    return preds

# %%
def comparar(df):
    '''
    Função para comparar predições de diferentes modelos com o target

    Args:
        df (pandas.df): dataframe com coluna '1' sendo os títulos/corpus, e '2' com o target/label
        
    Returns:
        list: Uma lista contendo 4 listas (uma para cada modelo: Decision Tree, Random Forest, Logistic Regression, SVC)
    '''
    DT, RF, LR, SVC = [], [], [], []
    for index, row in df.iterrows():
        text = row[0]
        target = row[1]
        pred = predict_title(text)
        pred['Target'] = [target]
        
        # Guardar as previsões em suas respectivas listas
        keys = [i for i in pred.keys()]
        DT.append(pred[keys[0]][0])
        RF.append(pred[keys[1]][0])
        LR.append(pred[keys[2]][0])
        SVC.append(pred[keys[3]][0])
        
        print(f'Notícia: {text}\n')
        for i in pred:
            print("\t{}\t{}".format(i, pred[i]))
        print('-----------------------------------------------------')
        print()
        
    return [DT, RF, LR, SVC]

# %% [markdown]
# ### Teste com dados separados pra validação

# %%
segundo_df_filtrado = segundo_df_filtrado[['corpo_texto', 'noticia_falsa']]

#segundo_df.columns = ['', '']

display(segundo_df_filtrado)
# Out:
#                                             corpo_texto  noticia_falsa
# 0     ['monitoramento', 'rápido', 'coberturas', 'vac...              1
# 1     diretora organização pan-americana saudar opar...              1
# 2     o pf polícia federal piauí deflagrar hoje o op...              1
# 3     o secretariar vigilância saudar ligar o o mini...              1
# 4     caracas ago afp o venezuela receber n sábado t...              1
# ...                                                 ...            ...
# 1220  pastor cidade lodi califórnio planejar o reali...              1
# 1221  atual pandemia coronavírus o parlamentar polôn...              1
# 1222  ['ofícios', 'circulares', 'ministério', 'saúde...              1
# 1223  circular rede social o escovar dentar o covid-...              0
# 1224  portugal registrar morte n sexta-feira consequ...              1
#
# [1225 rows x 2 columns]

# %%
predictions = comparar(segundo_df_filtrado)
# Out:
# /tmp/ipykernel_150192/3291409112.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text = row[0]
# /tmp/ipykernel_150192/3291409112.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   target = row[1]
# Notícia: ['monitoramento', 'rápido', 'coberturas', 'vacinais', 'póscampanhas', 'vacinação', 'brasil', '2008', '2011', '2012', 'serviços', 'personalizados', 'journal', 'scielo', 'analytics', 'google', 'scholar', 'h5m5', 'artigo', 'português', 'pdf', 'artigo', 'xml', 'referências', 'artigo', 'citar', 'artigo', 'scielo', 'analytics', 'tradução', 'automática', 'enviar',
administered', 'postcampaign', 'raising', 'vaccination', 'coverage', 'to', '995', 'in', 'that', 'year', 'in', '2012', 'postcampaign', 'coverage', 'ranged', 'between', '97', 'polio', 'and', 'hepatitis', 'b', 'and', '82', 'second', 'diphtheriatetanuspertussis', 'booster', 'lack', 'of', 'time', 'was', 'the', 'main', 'motive', 'nonvaccination', '436', 'in', '2011', 'and', '327', 'in', '2012', 'conclusion', 'rmc', 'is', 'useful', 'toolfor', 'evaluating', 'vaccination', 'coverage', 'and', 'reaching', 'those', 'not', 'vaccinated', 'in', 'addition', 'to', 'informing', 'interventions', 'key', 'words', 'immunization', 'programs', 'mass', 'vaccination', 'immunization', 'measlesmumpsrubella', 'vaccine', 'introdução', 'brasil', 'vacinas', 'utilizadas', 'prevenção', 'doenças', 'dois', 'sé ...
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: diretora organização pan-americana saudar opar carissa etienne alertar n quarta-feira o chance faltar insumo o intubação paciente infectar covid-19 hospital brasileiro o mortalidade aumentar ocorrer o taxar ocupação utis acima brasil declarar coletiva imprensar etienne haver morte covid-19 américas dia e março o brasil liderar país região mundo dever alertar o afirmar reforçar o necessidade medir protetivas o distanciamento social e o máscara conter o pandemia saltar caso covid-19 américas carissa etienne reforçar o flexibilizar medir
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o pf polícia federal piauí deflagrar hoje o operação campanile investigar suposto crime fraudar licitação falsidade ideológico e organização criminoso envolver contrato fechar o secretariar saudar piauí e empresar fornecedor equipamento hospitalar medicamento insumo e estruturar modular instalação hospital temporário recurso destinar o o combater o o coronavírus cercar policiar federar e auditor controladoria-geral união cumprir mandar buscar e apreensão município teresina joca marcar parnaíba pelota rs e paulo sp ordem expedir tribunal regional federal 1ª região trf-1 acordar o pf contrato suspeito firmar mediante dispensar licitação e custear recurso fundir nacional saudar e ministério saudar totalizar valorar pago r$ 33.725.000,00
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o secretariar vigilância saudar ligar o o ministério saudar registrar caso variante coronavírus teste realizar brasil respeitar o sábado acordar noto ministério caso variante b.1.1.7 identificar primeiramente reinar unir repassar conhecimento governar federal o d origem paulo caso e bahia o variante p.1 detectar japão pessoa manaus caso notificar o d origem amazona e detectar principalmente paulo goiá paraíba parar e bahia
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: caracas ago afp o venezuela receber n sábado tonelada ajudar humanitário doar espanha e portugal frente pandemia covid-19 informar representante governar socialista organização nação unir onu e união europeu ue o carregamento contribuição o união europeu governo espanha e portugal combater o pandemia covid-19 falar tonelada suprimento médico yván gil vice-reitor venezuela o europa declaração veicular televisão governamental o ajudar incluir vacinar patologia equipamento proteção equipamento saneamento água e diverso medicamento explicar gil durante o recepção avião aeroporto maiquetía localizar o cercar minuto terra caracas o ajudar humanitário implementar graça generosidade comunidade internacional e o o voar doar afirmar o gabinete coordenação assunto humanitário onu ocha twitter
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia:
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: governar e parlamentar debater o alcançar fogo o o banco central arsenal combater o efeito negativo pandemia coronavírus o governar incluir proposto emendar constituição pec o intervir diretamente mercar dispensar atuação mercar financeiro e capitar banco comprar carteiro crédito e título público privar hoje o bc autorização texto o o o jornal o s. paulo acesso o atuação direta feito durante o vigência calamidade situação gravar ruptura econômica reconhecido congresso nacional atuação estabilizar o mercar e evitar movimento generalizar fuga investidor feito federal reservar banco central unir e bcs mundo o arsenal incluir minutar pec apresentar semana passar bc o parlamentar apurar o jornal o s. paulo incluir proposto restrição comprar bc preocupação debater o o bc total atuação existir banco centrar independência
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o planar nacional imunização o covid-19 elaborar secretariar vigilância saudar ministério saudar entregar n sexta-feira eletronicamente ministrar eduardo pazuello o agu(advocacia união e o o stf(supremo tribunal federal cumprir o prazo estabelecer o cortar ciência e subsídio necessário julgamento o planar apresentar e detalhar população n quarta-feira ministério saúde.vale ressaltar o planar sofrer modificação durante o processar implementação acesse o ofício e o planar
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: unir registrar n terça-feira recordar caso covid-19 horar cifrar universidade johns hopkins centrar referência assunto total 2.706 óbito doença registrar dia acordar o contagem contínuo universidade o afp revisar noite s 20h30 horário recorde infectar registrar consecutivamente haver semana país o pessoa internar encontrar alto o comedir pandemia março paciente ocupar leito divulgar n terça-feira departamento saudar americano
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: ['adolescente', 'ainda', 'virgem', 'engravidado', 'tomar', 'vacina', 'verdade', 'home', 'sobre', 'efarsas', 'expediente', 'gilmar', 'lopes', 'riomar', 'bruno', 'arquivão', 'artigos', 'verdadeiro', 'falso', 'voltando', 'circular', 'anuncie', 'contato', '11', '960755663', 'faq', 'δημοφιλείς', 'τοποθεσίες', 'της', 'ελλάδας', 'και', 'όχι', 'μόνο', 'τουριστικά', 'προάστια', 'και', 'επίγεια', 'διασκέδαση', 'κριτική', 'από', 'το', 'znakifm', 'connect', 'with', 'us', 'efarsas', 'efarsas', 'home', 'sobre', 'efarsas', 'expediente', 'gilmar', 'lopes', 'riomar', 'bruno', 'arquivão', 'artigos', 'verdadeiro', 'falso', 'voltando', 'circular', 'anuncie', 'contato', '11', '960755663', 'faq', 'δημοφιλείς', 'τοποθεσίες', 'της', 'ελλάδας', 'και', 'όχι', 'μόνο', 'τουριστικά', 'προάστια', 'και', 'επίγεια', 'διασκέδαση', 'κριτική', 'από', 'το', 'znakifm', 'adolescente', 'ainda', 'virgem', 'engravidado', 'tomar', 'vacina', 'verdade', 'salvar', 'texto', 'falso', 'adolescente', 'ainda', 'virgem', 'engravidado', 'tomar', 'vacina', 'verdade', 'foto', 'tirada', 'deserto', 'saara', 'divulgada', 'nasa', 'marte', 'microfone', 'silvio', 'santos', 'cenográfico', 'música', 'tema', 'silvio', 'santos', 'denunciava', 'comunista', 'brasil', 'único', 'país', 'paga', 'salário', 'vereadores', 'adolescente', 'ainda', 'virgem', 'engravidado', 'tomar', 'vacina', 'verdade', 'porgilmar', 'lopes', 'publicado', '7', 'junho', '2018', 'salvar', 'texto', 'comentário', 'notícia', 'jovem', 'paraense',
', 'estágio', 'informações', 'classificadas', 'serviço', 'informação', 'cidadão', 'sic', 'relatório', 'monitoramento', 'lai', '2024', 'perguntas', 'frequentes', 'faq', 'corregedoria', 'dados', 'abertos', 'sei', 'banco', 'preços', 'concursos', 'seleções', 'gestão', 'sus', 'governança', 'pública', 'lei', 'geral', 'proteção', 'dados', 'pessoais', 'lgpd', 'transparência', 'prestação', 'contas', 'relatório', 'integrado', 'gestão', 'ministério', 'saúde', 'relatórios', 'gestão', 'secretaria', 'vigilância', 'saúde', 'relatórios' ...
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: janet diaz pesquisador oms organização mundial saudar anunciar n quarta-feira o agência recomendar fortemente o corticoides tratar paciente covid-19 efeito grave o evidência pesquisar produto diminuir o riscar morte produto testar dose reduzir hidrocortisona dexametasona e metilprednisolona aumentar o possibilidade sobrevivência paciente uti teste feito brasil reinar unir canadá espanha frança chino e unir o constatação remédio benéfico paciente doente independentemente faixar etário e sexo acordar estudo realizar n diferente país ficar constatar paciente grave vidar extra salvo graça o o tratamento resultar o oms falir forte recomendação cem paciente grave vidar salvo
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: Neste sábado (12), o Maranhão chegou a 152.944 pessoas curadas do novo coronavírus (Covid-19), de acordo com a Secretaria de Estado da Saúde (SES). Nas últimas 24 horas, mais 528 pessoas receberam alta médica no estado.  Com a atualização dos dados, o Maranhão chegou a marca de 162.476 casos confirmados e 3.369 mortes pelo novo coronavírus. Até o momento, 6.490 pacientes estão em tratamento contra a Covid-19 no estado e deste número, 6.034 estão em isolamento domiciliar, 252 internados em enfermarias e 149 em leitos de Unidade de Terapia Intensiva (UTI).  Desde o início da pandemia, 3.404 profissionais da saúde foram infectados pelo novo coronavírus. Deste número, 3.319 se recuperaram e 62 morreram.  Ao todo, 357.514 testes para a Covid-19 já foram realizados no Maranhão e 192.357 foram descartados.
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: ['análises', 'skip', 'to', 'content', 'home', 'últimas', 'editoriais', 'artigos', 'estudos', 'fact', 'checking', 'análises', 'vídeos', 'associese', 'estados', 'abaixo', 'assinado', 'carta', 'brasil', '2021', 'movimento', 'legislação', 'vida', 'excelentíssimos', 'membros', 'poder', 'judiciário', 'ministério', 'público', 'médicos', 'jornada', 'manifestos', 'manifestos', 'regionais', 'sugestões', 'imed', 'suporte', 'contato', 'help', 'desk', 'análises', 'aqui', 'ficam', 'análises', 'atemporais', 'produzidas', 'mpv', 'médicos', 'vida', 'articulistas', 'traduzidas', 'atuais', 'ainda', 'úteis', 'caso', 'evidências', 'análises', 'fiquem', 'ultrapassadas', 'retiradas', 'deste', 'índice', 'bmj', 'declínio', 'ciência', 'fda', 'tornou', 'incontrolável', '25', 'maio', '2023', 'pode', 'feito', 'sobre', 'situação', 'deprimente', 'pergunta', 'autor', 'primeiro', 'passo', 'admitir', 'problema', 'declínio', 'ciência', 'fda', 'tornou', 'incontrolável', 'editorial', 'podcast', 'ciência', 'suja', 'fará', 'episódio', 'sobre', 'saiba', 'fatos', 'vão', 'ignorar', '30', 'março', '2023', 'exatamente', 'semana', 'brasil', 'atinge', '
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: circular rede social o escovar dentar o covid-19 preciso trocar o melhorar paciente o coronavírus ficar ativo cerda dentista recomendar escovar trocar o cerda deformar haver embasamento científico o tesar cerda reter o coronavírus e manter o escovar levar o caso reinfecção especialista entrevistar cbn o mensagem “ o covid-19 precisar trocar o escovar dental período o salivar conter concentração vírus e bactéria causar infecção secundário ”
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: portugal registrar morte n sexta-feira consequência covid-19 o doença provocar coronavírus e superar o marcar óbito durante o pandemia dia acabar o emergência decretar causar pandemia acordar apresentar direção saudar 25.351 caso infecção patógeno o o indicar taxar crescimento 1,2 e 1.007 óbito atualmente país pessoa internar hospital o dia d paciente unidade terapia intensivo acima desejar controlar dia afirmar o ministro saudar marta temer
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------

# %%
# Calcula score de cada método para df externo
target = segundo_df_filtrado['noticia_falsa'].tolist()

acc_dt_e = cross_val_score(modelo_ad, X, y, scoring='accuracy')
acc_rf_e = cross_val_score(modelo_rf, X, y, scoring='accuracy')
acc_lr_e = cross_val_score(modelo_lr, X, y, scoring='accuracy')
acc_svc_e = cross_val_score(modelo_svm, X, y, scoring='accuracy')

prec_dt_e = cross_val_score(modelo_ad, X, y, scoring='precision')
prec_rf_e = cross_val_score(modelo_rf, X, y, scoring='precision')
prec_lr_e = cross_val_score(modelo_lr, X, y, scoring='precision')
prec_svc_e = cross_val_score(modelo_svm, X, y, scoring='precision')

acc_dt_mean = acc_dt_e.mean()
acc_rf_mean = acc_rf_e.mean()
acc_lr_mean = acc_lr_e.mean()
acc_svc_mean = acc_svc_e.mean()

acc_dt_std = acc_dt_e.std()
acc_rf_std = acc_rf_e.std()
acc_lr_std = acc_lr_e.std()
acc_svc_std = acc_svc_e.std()

prec_dt_mean = prec_dt_e.mean()
prec_rf_mean = prec_rf_e.mean()
prec_lr_mean = prec_lr_e.mean()
prec_svc_mean = prec_svc_e.mean()

prec_dt_std = prec_dt_e.std()
prec_rf_std = prec_rf_e.std()
prec_lr_std = prec_lr_e.std()
prec_svc_std = prec_svc_e.std()

print('---- Decision Tree ----')
print(f'Acurácia: {acc_dt_mean:.3f} ± {acc_dt_std:.3f}\nPrecisão: {prec_dt_mean:.3f} ± {prec_dt_std:.3f}')
print()
print('---- Random Forest ----')
print(f'Acurácia: {acc_rf_mean:.3f} ± {acc_rf_std:.3f}\nPrecisão: {prec_rf_mean:.3f} ± {prec_rf_std:.3f}')
print()
print('---- Linear Regression ----')
print(f'Acurácia: {acc_lr_mean:.3f} ± {acc_lr_std:.3f}\nPrecisão: {prec_lr_mean:.3f} ± {acc_lr_std:.3f}')
print()
print('---- SVC ----')
print(f'Acurácia: {acc_svc_mean:.3f} ± {acc_svc_std:.3f}\nPrecisão: {prec_svc_mean:.3f} ± {acc_svc_std:.3f}')
print()
# Out:
# ---- Decision Tree ----
# Acurácia: 0.856 ± 0.016
# Precisão: 0.886 ± 0.019
#
# ---- Random Forest ----
# Acurácia: 0.930 ± 0.007
# Precisão: 0.920 ± 0.011
#
# ---- Linear Regression ----
# Acurácia: 0.921 ± 0.008
# Precisão: 0.901 ± 0.008
#
# ---- SVC ----
# Acurácia: 0.941 ± 0.011
# Precisão: 0.940 ± 0.011

# %%
# Definindo os dados
accuracy_list = [acc_dt_mean, acc_rf_mean, acc_lr_mean, acc_svc_mean]
precision_list = [prec_dt_mean, prec_rf_mean, prec_lr_mean, prec_svc_mean]
acc_std_list = [acc_dt_std, acc_rf_std, acc_lr_std, acc_svc_std]
prec_std_list = [prec_dt_std, prec_rf_std, prec_lr_std, prec_svc_std]
model_labels = ['Árvore de Decisão', 'Floresta Aleatória', 'Regressão Logística', 'SVM']
colors = ['red', 'orange', 'pink', 'purple']

# Posições das barras para os grupos
x = np.arange(2)  # Um ponto para "Precisão" e outro para "Acurácia"
width = 0.15      # Largura das barras

# Criando o gráfico sem zoom
fig, ax = plt.subplots(figsize=(8, 6))
for i in range(len(model_labels)):
    # Precisão
    ax.bar(x[0] + i * width - (1.5 * width), precision_list[i], width, label=model_labels[i], color=colors[i])
    ax.errorbar(x[0] + i * width - (1.5 * width), precision_list[i], yerr=prec_std_list[i], fmt='o', color='black', capsize=5)
    # Acurácia
    ax.bar(x[1] + i * width - (1.5 * width), accuracy_list[i], width, color=colors[i])
    ax.errorbar(x[1] + i * width - (1.5 * width), accuracy_list[i], yerr=acc_std_list[i], fmt='o', color='black', capsize=5)

# Configurando os rótulos e título
ax.set_xlabel('Métrica')
ax.set_ylabel('Valores')
ax.set_title('Precisão e Acurácia dos Modelos para o Corpo dos Textos (Sem Zoom)')
ax.set_xticks(x)
ax.set_xticklabels(['Precisão', 'Acurácia'])
ax.legend()

# Exibindo o gráfico sem zoom
plt.show()

# Criando o gráfico com zoom
fig, ax = plt.subplots(figsize=(8, 6))
for i in range(len(model_labels)):
    # Precisão
    ax.bar(x[0] + i * width - (1.5 * width), precision_list[i], width, label=model_labels[i], color=colors[i])
    ax.errorbar(x[0] + i * width - (1.5 * width), precision_list[i], yerr=prec_std_list[i], fmt='o', color='black', capsize=5)
    # Acurácia
    ax.bar(x[1] + i * width - (1.5 * width), accuracy_list[i], width, color=colors[i])
    ax.errorbar(x[1] + i * width - (1.5 * width), accuracy_list[i], yerr=acc_std_list[i], fmt='o', color='black', capsize=5)

# Configurando os rótulos e título
ax.set_xlabel('Métrica')
ax.set_ylabel('Valores')
ax.set_title('Precisão e Acurácia dos Modelos para o Corpo dos Textos (Com Zoom)')
ax.set_xticks(x)
ax.set_xticklabels(['Precisão', 'Acurácia'])
ax.legend()

# Definindo o limite do eixo y para dar o "zoom"
plt.ylim(0.75, 1)

# Exibindo o gráfico com zoom
plt.show()
