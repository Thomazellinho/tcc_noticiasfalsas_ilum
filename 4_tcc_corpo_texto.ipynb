# %%
# Importações

import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn import svm
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    cohen_kappa_score,
    roc_auc_score,
    confusion_matrix
)

import pandas as pd
import numpy as np

from nltk.corpus import stopwords

import re

import itertools

# Cross validate

from sklearn.model_selection import cross_validate, cross_val_score

# Modelos

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

import matplotlib.pyplot as plt
# Out:
# /home/ABTLUS/pedro220058/.local/lib/python3.10/site-packages/nltk/metrics/association.py:26: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 1.21.6)
#   from scipy.stats import fisher_exact

# %%
# Importação do Dataframe contendo títulos de notícias relacionadas a saúde.

dataframe = pd.read_csv('dados/combined_df.zip')

display(dataframe)
# Out:
#                                                   title  \
# 0     Espanha reabrirá fronteiras terrestres França ...
# 1     Rússia proíbe entrada chineses território covi...
# 2     Covid-19: 'Pandemia Brasil começou três linhag...
# 3     nota conjunta ministério relações exteriores m...
# 4     ministério saúde vai repassar r$ 136 milhões c...
# ...                                                 ...
# 5119  Associação Brasileira Infectologia (ABI) obrig...
# 5120  maioria norte-americanos preocupada segurança ...
# 5121  Coronavírus: confira próximas lives música cur...
# 5122           É enganoso Coronavac proibida EUA Europa
# 5123  Unimed Brusque envia kit cloroquina médicos "p...
#
#                                                    link                 date  \
# 0     https://noticias.uol.com.br/ultimas-noticias/a...    04/06/2020 08h27
# 1     https://noticias.uol.com.br/ultimas-noticias/a...    18/02/2020 15h08
# 2     https://g1.globo.com/bemestar/coronavirus/noti...    13/11/2020 08h55
# 3     https://www.gov.br/saude/pt-br/assuntos/notici...  Data não disponível
# 4     https://www.gov.br/saude/pt-br/assuntos/notici...  Data não disponível
# ...                                                 ...                  ...
# 5119  https://www.boatos.org/saude/associacao-de-inf...           22/03/2021
# 5120  https://medicospelavidacovid19.com.br/noticias...  Data não disponível
# 5121  https://entretenimento.uol.com.br/noticias/red...    10/04/2020 04h00
# 5122  https://projetocomprova.com.br/publicações/e-e...           2021/05/12
# 5123  https://noticias.uol.com.br/saude/ultimas-noti...    19/07/2020 04h00
#
#                    Site  noticia_falsa  \
# 0                   NaN              1
# 1                   NaN              1
# 2                   NaN              1
# 3          gov.br saude              1
# 4          gov.br saude              1
# ...                 ...            ...
# 5119                NaN              0
# 5120  Médicos Pela Vida              0
# 5121                NaN              1
# 5122                NaN              0
# 5123                NaN              1
#
#                                             corpo_texto
# 0     o ministro turismo espanha reyes maroto anunci...
# 1     o rússia anunciar hoje proibir o entrar cidadã...
# 2     pensar trabalhar dinâmico transmissão doença i...
# 3     ['nota', 'conjunta', 'ministério', 'relações',...
# 4     ['ministério', 'saúde', 'vai', 'repassar', 'r'...
# ...                                                 ...
# 5119  denúncia gravar o associação brasileiro infect...
# 5120  ['maioria', 'norteamericanos', 'preocupada', '...
# 5121  apresentação artista brasileiro web o sucesso ...
# 5122  vídeo facebook afirmar o vacinar coronavac lab...
# 5123  o unidade unimed operador plano saudar país br...
#
# [5124 rows x 6 columns]

# %%
# Cria dataframe para processamento
df = dataframe.copy()
df_sorted = df.sort_values(by='noticia_falsa').reset_index(drop=True)

# Transformar a coluna título em string
df_sorted['title'] = df_sorted['title'].astype(str)

# %%
### Filtrando notícias com valores 0 e 1
noticias_falsa_0 = df_sorted[df_sorted['noticia_falsa'] == 0]
noticias_falsa_1 = df_sorted[df_sorted['noticia_falsa'] == 1] # Aqui estão representadas as notícias verdadeiras

### Selecionar, aleatoriamente, 1000 notícias com valores 0 e 1500 com valores 1
amostra_0 = noticias_falsa_0.sample(n=1000, random_state=42)
amostra_1 = noticias_falsa_1.sample(n=1500, random_state=42)

# Criando um novo dataframe com estas notícias
novo_df = pd.concat([amostra_0, amostra_1])

# Resetando o index
novo_df = novo_df.sample(frac=1, random_state=24).reset_index(drop=True)

display(novo_df)
# Out:
#                                                   title  \
# 0           Placar mostra Pacheco frente disputa Senado
# 1     Reino Unido inicia nova abordagem teste massa ...
# 2     Publicação engana dizer pandemia declínio após...
# 3     Guedes defende empresários comprem vacina pede...
# 4     fake nóis previsão furar vidente sobrar corona...
# ...                                                 ...
# 2495  Bahrein segundo país aprovar vacina Pfizer/Bio...
# 2496  É #FAKE vídeo mostre Bell Marques falando novo...
# 2497                                 margareth dalcolmo
# 2498  Veja #FATO #FAKE declarações médica Nise Yamag...
# 2499  vídeo papar francisco impedir fiel beijar anel...
#
#                                                    link                 date  \
# 0     https://noticias.uol.com.br/ultimas-noticias/a...    23/01/2021 13h45
# 1     https://g1.globo.com/bemestar/coronavirus/noti...    03/11/2020 09h31
# 2     https://projetocomprova.com.br/publicações/pub...           2020/07/23
# 3     https://economia.uol.com.br/noticias/redacao/2...    25/03/2021 18h34
# 4     https://www.e-farsas.com/fake-em-nois-as-previ...           14/07/2020
# ...                                                 ...                  ...
# 2495  https://noticias.uol.com.br/ultimas-noticias/a...    04/12/2020 18h14
# 2496  https://g1.globo.com/fato-ou-fake/coronavirus/...           07/05/2020
# 2497  https://www.gov.br/saude/pt-br/campanhas-da-sa...  Data não disponível
# 2498  https://g1.globo.com/fato-ou-fake/noticia/2021...           01/06/2021
# 2499  https://www.e-farsas.com/o-video-do-papa-franc...           30/03/2019
#
#               Site  noticia_falsa  \
# 0              NaN              1
# 1              NaN              1
# 2              NaN              0
# 3              NaN              1
# 4              NaN              0
# ...            ...            ...
# 2495           NaN              1
# 2496           NaN              0
# 2497  gov.br saude              1
# 2498           NaN              0
# 2499           NaN              0
#
#                                             corpo_texto
# 0     Rodrigo Pacheco (DEM-MG), candidato apoiado pe...
# 1     o reinar unir lançar programar pilotar teste m...
# 2     site atualizados portal transparência registra...
# 3     o ministrar economia paulo guedes defender hoj...
# 4     prever o futurar filmar livrar desenhar e séri...
# ...                                                 ...
# 2495  O Bahrein anunciou hoje a aprovação urgente da...
# 2496  circular rede social vídeo mostrar o cantor be...
# 2497  ['margareth', 'dalcolmo', 'ministério', 'saúde...
# 2498  o médico nise yamaguchi prestar depoimento n t...
# 2499  o vídeo surgir rede social março e deixar gent...
#
# [2500 rows x 6 columns]

# %%
# Agora, separaremos uma porção para validação com dados externos

### Separar as notícias restantes
restantes_0 = noticias_falsa_0.drop(amostra_0.index)
restantes_1 = noticias_falsa_1.drop(amostra_1.index)

# Selecionar 449 notícias restantes com valor 0 e 800 com valor 1
amostra_0_restante = restantes_0
amostra_1_restante = restantes_1.sample(n=800, random_state=42)

# Criar um novo dataframe
segundo_df = pd.concat([amostra_0_restante, amostra_1_restante])

# Bagunçar o df
segundo_df = segundo_df.sample(frac=1, random_state=48).reset_index(drop=True)

display(segundo_df)
# Out:
#                                                   title  \
# 0     População desocupada somou 11,8 milhões 3ª sem...
# 1     Em meio desgaste Mandetta, Bolsonaro convida O...
# 2     Anvisa cobra mudança comportamento diz vacina ...
# 3     "Caminhão cata veio" circula Goiânia pede idos...
# 4     Não faltará dinheiro quiser vacinar, diz Sachsida
# ...                                                 ...
# 1239  Coronavírus: mortes suspeitas acendem alerta s...
# 1240  'Saímos menos 2 mil', explica Gabbardo sobre p...
# 1241  Comediante Dave Chappelle covid-19; shows canc...
# 1242        É falso número casos covid-19 menor oficial
# 1243  Presidente mexicano diz Rússia fornecerá 24 mi...
#
#                                                    link  \
# 0     https://economia.uol.com.br/noticias/estadao-c...
# 1     https://economia.uol.com.br/colunas/carla-arau...
# 2     https://noticias.uol.com.br/ultimas-noticias/a...
# 3     https://noticias.uol.com.br/cotidiano/ultimas-...
# 4     https://economia.uol.com.br/noticias/reuters/2...
# ...                                                 ...
# 1239  https://noticias.uol.com.br/saude/ultimas-noti...
# 1240  https://noticias.uol.com.br/ultimas-noticias/a...
# 1241  https://tvefamosos.uol.com.br/noticias/redacao...
# 1242  https://projetocomprova.com.br/publicações/e-f...
# 1243  https://noticias.uol.com.br/ultimas-noticias/r...
#
#                                                  date Site  noticia_falsa  \
# 0                                   10/07/2020 10h28   NaN              1
# 1     06/04/2020 15h09Atualizada em 06/04/2020 17h27   NaN              1
# 2                                   17/01/2021 11h41   NaN              1
# 3                                   31/03/2020 14h48   NaN              1
# 4                                   08/01/2021 12h02   NaN              1
# ...                                               ...  ...            ...
# 1239                                27/03/2020 08h58   NaN              1
# 1240                                09/08/2020 11h31   NaN              1
# 1241                                22/01/2021 08h24   NaN              1
# 1242                                       2020/06/01  NaN              0
# 1243                                25/01/2021 19h51   NaN              1
#
#                                             corpo_texto
# 0     o taxar desocupação ficar 12,3 semana o junho ...
# 1     dia falar o caneta eventualmente tirar governa...
# 2     o diretor-presidente agência nacional vigilânc...
# 3     ação bem-humorada alertar idoso perigo sair s ...
# 4     brasília reuters faltar dinheiro o vacinação p...
# ...                                                 ...
# 1239  familiar esperar semana respostar o testar cov...
# 1240  ex-secretário-executivo ministério saudar joão...
# 1241  o comediante dave chappelle popular stand-up n...
# 1242  o o contrário apresentador canal youtube morte...
# 1243  o rússia fornecer milhão dose vacinar sputnik ...
#
# [1244 rows x 6 columns]

# %%
# Checar os títulos únicos em cada Dataframe

corpo_texto_novo_df = set(novo_df['corpo_texto'].unique())
corpo_texto_segundo_df = set(segundo_df['corpo_texto'].unique())

# Vendo se há títulos repetidos

corpo_texto_repetidos = corpo_texto_novo_df.intersection(corpo_texto_segundo_df)

print(f"Corpos do texto repetidos: {corpo_texto_repetidos}")

# Remover do 'segundo_df' os títulos repetidos

segundo_df_filtrado = segundo_df[~segundo_df['corpo_texto'].isin(corpo_texto_novo_df)]

segundo_df_filtrado = segundo_df_filtrado.reset_index(drop=True)

display(segundo_df_filtrado)
# Out:
# Corpos do texto repetidos: {"['ministério', 'saúde', 'ir', 'conteúdo', '1', 'ir', 'página', 'inicial', '2', 'ir', 'menu', 'navegação', '3', 'ir', 'busca', '4', 'ir', 'mapa', 'site', '5', 'atenção', 'navegador', 'pode', 'executar', 'javascript', 'alguns', 'recursos', 'podem', 'funcionar', 'corretamente', 'portal', 'govbr', 'acesso', 'rápido', 'acesso', 'rápido', 'órgãos', 'governo', 'acesso', 'informação', 'legislação', 'acessibilidade', 'pt', 'escolher', 'idioma', 'en', 'es', 'redefinir', 'cookies', 'mudar', 'modo', 'alto', 'contraste', 'abrir', 'menu', 'principal', 'navegação', 'ministério', 'saúde', 'termos', 'buscados', 'assinatura', 'enem', 'imposto', 'renda', 'mei', 'inss', 'termos', 'buscados', 'assinatura', 'enem', 'imposto', 'renda', 'saudebrasildoaçãodesangueconferencialivreapssapssaude', 'cienciacalendariodevacinacaoestágioretomada', 'obrasouvsusaedesaegyptiarboviroseschikungunyadenguedenguevacinacaozikaviruscoescoedenguecombateaomosquito', 'denguenasescolas', 'denguenasescolasgripebrasilunidocontradenguevacinacaonasescolasmeususdigitalabrilpelasegurançadopacientecampanhassemsbacovid19fnsusnoticiasparaosestadosoropoucheseminariosesaicnieproqualibrasilsaudavelvarioladosmacacoscoqueluchempox', 'govbr', 'serviços', 'buscar', 'serviços', 'categorias', 'órgãos', 'estados', 'serviços', 'público', 'alvo', 'cidadãos', 'empresas', 'órgãos', 'entidades', 'públicas', 'demais', 'segmentos', 'ongs', 'organizações', 'sociais', 'etc', 'servidor', 'público', 'temas', 'destaque', 'orçamento', 'nacional', 'redes', 'atendimento', 'governo', 'federal', 'proteção', 'dados', 'pessoais', 'serviços', 'imigrantes', 'política', 'orçamento', 'educacionais', 'bolsas', 'estudo', 'financiamentos', 'estudantis', 'educação', 'profissional', 'tecnológica', 'educação', 'profissional', 'jovens', 'adultos', 'trabalho', 'emprego', 'serviços', 'pessoas', 'deficiência', 'combate', 'discriminação', 'racial', 'política', 'proteção', 'social', 'política', 'mulheres', 'saúde', 'reprodutiva', 'mulher', 'cuidados', 'primeira', 'infância', 'habitação', 'popular', 'controle', 'poluição', 'resíduos', 'sólidos', 'notícias', 'serviços', 'cidadão', 'saúde', 'agricultura', 'pecuária', 'cidadania', 'assistência', 'social', 'ciência', 'tecnologia', 'comunicação', 'cultura', 'esporte', 'economia', 'gestão', 'pública', 'educação', 'pesquisa', 'energia', 'forças', 'armadas', 'defesa', 'civil', 'infraestrutura', 'justiça', 'segurança', 'meio', 'ambiente', 'trabalho', 'previdência', 'turismo', 'galeria', 'aplicativos', 'acompanhe', 'planalto', 'navegação', 'acessibilidade', 'mapa', 'site', 'termo', 'uso', 'aviso', 'privacidade', 'consultar', 'solicitações', 'órgãos', 'governo', 'dentro', 'govbr', 'dúvidas', 'frequentes', 'relação', 'portal', 'govbr', 'dúvidas', 'frequentes', 'conta', 'govbr', 'ajuda', 'navegar', 'portal', 'conheça', 'elementos', 'portal', 'política', 'eparticipação', 'termos', 'uso', 'governo', 'digital', 'guia', 'edição', 'serviços', 'portal', 'govbr', 'canais', 'executivo', 'federal', 'dados', 'governo', 'federal', 'dados', 'abertos', 'painel', 'estatístico', 'pessoal', 'painel', 'compras', 'governo', 'federal', 'acesso', 'informação', 'empresas', 'negócios', 'simplifique', 'links', 'úteis', 'galeria', 'aplicativos', 'participe', 'galeria', 'aplicativos', 'participe', 'redes', 'sociais', 'twitter', 'youtube', 'facebook', 'instagram', 'soundcloud', 'flickr', 'linkedin', 'kwai', 'tiktok', 'aqui', 'página', 'inicial', 'busca', 'busca', 'info', 'saudebrasildoaçãodesangueconferencialivreapssapssaude', 'cienciacalendariodevacinacaoestágioretomada', 'obrasouvsusaedesaegyptiarboviroseschikungunyadenguedenguevacinacaozikaviruscoescoedenguecombateaomosquito', 'denguenasescolas', 'denguenasescolasgripebrasilunidocontradenguevacinacaonasescolasmeususdigitalabrilpelasegurançadopacientecampanhassemsbacovid19fnsusnoticiasparaosestadosoropoucheseminariosesaicnieproqualibrasilsaudavelvarioladosmacacoscoqueluchempox', 'redefinir', 'cookies', 'redes', 'sociais', 'twitter', ' ...
#                                                   title  \
# 0     População desocupada somou 11,8 milhões 3ª sem...
# 1     Em meio desgaste Mandetta, Bolsonaro convida O...
# 2     Anvisa cobra mudança comportamento diz vacina ...
# 3     "Caminhão cata veio" circula Goiânia pede idos...
# 4     Não faltará dinheiro quiser vacinar, diz Sachsida
# ...                                                 ...
# 1212  Coronavírus: mortes suspeitas acendem alerta s...
# 1213  'Saímos menos 2 mil', explica Gabbardo sobre p...
# 1214  Comediante Dave Chappelle covid-19; shows canc...
# 1215        É falso número casos covid-19 menor oficial
# 1216  Presidente mexicano diz Rússia fornecerá 24 mi...
#
#                                                    link  \
# 0     https://economia.uol.com.br/noticias/estadao-c...
# 1     https://economia.uol.com.br/colunas/carla-arau...
# 2     https://noticias.uol.com.br/ultimas-noticias/a...
# 3     https://noticias.uol.com.br/cotidiano/ultimas-...
# 4     https://economia.uol.com.br/noticias/reuters/2...
# ...                                                 ...
# 1212  https://noticias.uol.com.br/saude/ultimas-noti...
# 1213  https://noticias.uol.com.br/ultimas-noticias/a...
# 1214  https://tvefamosos.uol.com.br/noticias/redacao...
# 1215  https://projetocomprova.com.br/publicações/e-f...
# 1216  https://noticias.uol.com.br/ultimas-noticias/r...
#
#                                                  date Site  noticia_falsa  \
# 0                                   10/07/2020 10h28   NaN              1
# 1     06/04/2020 15h09Atualizada em 06/04/2020 17h27   NaN              1
# 2                                   17/01/2021 11h41   NaN              1
# 3                                   31/03/2020 14h48   NaN              1
# 4                                   08/01/2021 12h02   NaN              1
# ...                                               ...  ...            ...
# 1212                                27/03/2020 08h58   NaN              1
# 1213                                09/08/2020 11h31   NaN              1
# 1214                                22/01/2021 08h24   NaN              1
# 1215                                       2020/06/01  NaN              0
# 1216                                25/01/2021 19h51   NaN              1
#
#                                             corpo_texto
# 0     o taxar desocupação ficar 12,3 semana o junho ...
# 1     dia falar o caneta eventualmente tirar governa...
# 2     o diretor-presidente agência nacional vigilânc...
# 3     ação bem-humorada alertar idoso perigo sair s ...
# 4     brasília reuters faltar dinheiro o vacinação p...
# ...                                                 ...
# 1212  familiar esperar semana respostar o testar cov...
# 1213  ex-secretário-executivo ministério saudar joão...
# 1214  o comediante dave chappelle popular stand-up n...
# 1215  o o contrário apresentador canal youtube morte...
# 1216  o rússia fornecer milhão dose vacinar sputnik ...
#
# [1217 rows x 6 columns]

# %%
# Variáveis para padronização/configuração

scores = ['accuracy', 'precision', 'roc_auc']
usar_links = False

# %%
# Checar se há títulos vazios
non_empty_titles = novo_df['corpo_texto'].apply(lambda x: len(x.strip()) > 0)
non_empty_links = novo_df['link'].apply(lambda x: len(x.strip()) > 0)

# Checar o resultado
print(non_empty_titles.head())
print("Há documentos vazios?", not non_empty_titles.all())
print("Há links vazios?", not non_empty_links.all())
print("Número de documentos vazios:", (~non_empty_titles).sum())
print("Número de links vazios:", (~non_empty_links).sum())
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: corpo_texto, dtype: bool
# Há documentos vazios? False
# Há links vazios? False
# Número de documentos vazios: 0
# Número de links vazios: 0

# %%
# Iniciar o processo de TF-IDF
tfidf_vectorizer = TfidfVectorizer()

# Nesta célula, será aplicado o TF-IDF aos títulos das notícias, caso não haja nenhum vazio
temp_tit = novo_df['corpo_texto'].tolist()
if non_empty_titles.all():
    titles_tfidf = tfidf_vectorizer.fit_transform(temp_tit)
    print('TF-IDF aplicado com sucesso.')
    tfidf = titles_tfidf
else:
    print('Há documentos vazios ou apenas stop words.')
# Out:
# TF-IDF aplicado com sucesso.

# %%
def split_and_clean(link):
# Dividir o link por '/', '-', '%', '.', e ':'
    words = re.split(r'[/\-\%\.\:\_]', link)
    # Remover palavras indesejadas, stopwords e letras isoladas, mantendo acentos
    unwanted = {'https', 'www', 'com', 'br', 'pt', 'html', 'htm', 'ghtml', 'php'}
    cleaned_words = [
    word for word in words
    if not any(unwanted_word in word.lower() for unwanted_word in unwanted)
    and len(word) > 1
    ]
    return cleaned_words

if usar_links:

    # Tratando os links
    df['processed_links'] = df['link'].apply(split_and_clean)

    # TF-IDF para os combinação título e link
    temp_link = [' '.join(i) for i in df['processed_links']]
    temp_tit_link = [' '.join(list(a)) for a in zip(temp_tit, temp_link)]
    print(temp_tit_link)
    if non_empty_links.all():
        tit_link_tfidf = tfidf_vectorizer.fit_transform(temp_tit_link)
        print('TF-IDF aplicado com sucesso.')
        tfidf = tit_link_tfidf
    else:
        print('Há items vazios ou apenas stop words.')

# %%
# Criação de vetores
X = tfidf
y = novo_df['noticia_falsa']

corpos_texto = novo_df['corpo_texto'].tolist()

print("Dimensões de X:", X.shape)
print("Dimensões de y:", y.shape)
# Out:
# Dimensões de X: (2500, 29053)
# Dimensões de y: (2500,)

# %%
# Padronizando scores para todos os modelos.

scores = ['accuracy', 'precision', 'roc_auc']

# %% [markdown]
# ### Árvore de Decisão

# %%
# Cria modelo
modelo_ad = DecisionTreeClassifier()
modelo_ad

# Validação cruzada
resultados_ad = cross_validate(modelo_ad, X, y, scoring=scores)

acc_ad = resultados_ad['test_accuracy'].mean()
prec_ad = resultados_ad['test_precision'].mean()
rocauc_ad = resultados_ad['test_roc_auc'].mean()
print(f'Acurácia: {acc_ad:.3f}\nPrecisão: {prec_ad:.3f}\nROC-AUC: {rocauc_ad:.3f}')
# Out:
# Acurácia: 0.845
# Precisão: 0.870
# ROC-AUC: 0.838

# %% [markdown]
# ### Floresta Aleatória

# %%
# Cria modelo
modelo_rf = RandomForestClassifier()
modelo_rf

# Validação cruzada
resultados_rf = cross_validate(modelo_rf, X, y, scoring=scores)

acc_rf = resultados_rf['test_accuracy'].mean()
prec_rf = resultados_rf['test_precision'].mean()
rocauc_rf = resultados_rf['test_roc_auc'].mean()
print(f'Acurácia: {acc_rf:.3f}\nPrecisão: {prec_rf:.3f}\nROC-AUC: {rocauc_rf:.3f}')
# Out:
# Acurácia: 0.934
# Precisão: 0.925
# ROC-AUC: 0.978

# %% [markdown]
# ### Regressão Logística

# %%
# Cria modelo
modelo_lr = LogisticRegression()
modelo_lr

# Validação cruzada
resultados_lr = cross_validate(modelo_lr, X, y, scoring=scores)

acc_lr = resultados_lr['test_accuracy'].mean()
prec_lr = resultados_lr['test_precision'].mean()
rocauc_lr = resultados_lr['test_roc_auc'].mean()
print(f'Acurácia: {acc_lr:.3f}\nPrecisão: {prec_lr:.3f}\nROC-AUC: {rocauc_lr:.3f}')
# Out:
# Acurácia: 0.921
# Precisão: 0.898
# ROC-AUC: 0.974

# %% [markdown]
# ### SVC

# %%
# Parâmetros
C = 77
kernel = 'rbf'
gamma = 0.01

# Cria modelo
modelo_svm = svm.SVC(C=C, kernel=kernel, gamma=gamma)

# Validação cruzada
resultados_svm = cross_validate(modelo_svm, X, y, scoring=scores)

acc_svm = resultados_svm['test_accuracy'].mean()
prec_svm = resultados_svm['test_precision'].mean()
rocauc_svm = resultados_svm['test_roc_auc'].mean()
print(f'Acurácia: {acc_svm:.3f}\nPrecisão: {prec_svm:.3f}\nROC-AUC: {rocauc_svm:.3f}')
# Out:
# Acurácia: 0.935
# Precisão: 0.933
# ROC-AUC: 0.977

# %% [markdown]
# ### Função de comparação

# %%
stop_words = set(stopwords.words('portuguese'))

def trata_padrao(titulo, usar_links=False, link=None):
    '''
    Função para padronizar o tratamento dos títulos.

    Args:
    titulo (str) = título da notícia
    usar_links (bool) = usar ou não o link
    link (str) = link da notícia
    '''

    # Pré-processamento do titulo

    titulo = str(titulo).lower()
    titulo = nltk.word_tokenize(titulo)
    titulo = [word for word in titulo if word not in stop_words]
    titulo = [' '.join(titulo)]
    temp_tit = titulo

    # se usar link, pre processar link
    if usar_links:
        link = [split_and_clean(link)]
        temp_link = [' '.join(i) for i in link]
        print(temp_tit,temp_link)
        temp_tit_link = [' '.join(list(a)) for a in zip(temp_tit, temp_link)]
        processed = temp_tit_link
    else:
        processed = titulo

    return processed

# %%
# Define modelos para teste
modelos = [modelo_ad, modelo_rf, modelo_lr, modelo_svm]

# Treina modelos com todos os dados
for modelo in modelos:
    modelo.fit(X, y)

# Função para predizer novos títulos
def predict_title(titulo):
    preprocessed_title = trata_padrao(titulo)

    tfidf_vector = tfidf_vectorizer.transform(preprocessed_title)
    preds = dict()

    for modelo in modelos:
        preds[modelo] = modelo.predict(tfidf_vector)

    return preds

# %%
def comparar(df):
    '''
    Função para comparar predições de diferentes modelos com o target

    Args:
        df (pandas.df): dataframe com coluna '1' sendo os títulos/corpus, e '2' com o target/label
        
    Returns:
        list: Uma lista contendo 4 listas (uma para cada modelo: Decision Tree, Random Forest, Logistic Regression, SVC)
    '''
    DT, RF, LR, SVC = [], [], [], []
    for index, row in df.iterrows():
        text = row[0]
        target = row[1]
        pred = predict_title(text)
        pred['Target'] = [target]
        
        # Guardar as previsões em suas respectivas listas
        keys = [i for i in pred.keys()]
        DT.append(pred[keys[0]][0])
        RF.append(pred[keys[1]][0])
        LR.append(pred[keys[2]][0])
        SVC.append(pred[keys[3]][0])
        
        print(f'Notícia: {text}\n')
        for i in pred:
            print("\t{}\t{}".format(i, pred[i]))
        print('-----------------------------------------------------')
        print()
        
    return [DT, RF, LR, SVC]

# %% [markdown]
# ### Teste com dados separados pra validação

# %%
segundo_df_filtrado = segundo_df_filtrado[['corpo_texto', 'noticia_falsa']]

#segundo_df.columns = ['', '']

display(segundo_df_filtrado)
# Out:
#                                             corpo_texto  noticia_falsa
# 0     o taxar desocupação ficar 12,3 semana o junho ...              1
# 1     dia falar o caneta eventualmente tirar governa...              1
# 2     o diretor-presidente agência nacional vigilânc...              1
# 3     ação bem-humorada alertar idoso perigo sair s ...              1
# 4     brasília reuters faltar dinheiro o vacinação p...              1
# ...                                                 ...            ...
# 1212  familiar esperar semana respostar o testar cov...              1
# 1213  ex-secretário-executivo ministério saudar joão...              1
# 1214  o comediante dave chappelle popular stand-up n...              1
# 1215  o o contrário apresentador canal youtube morte...              0
# 1216  o rússia fornecer milhão dose vacinar sputnik ...              1
#
# [1217 rows x 2 columns]

# %%
predictions = comparar(segundo_df_filtrado)
# Out:
# Notícia: o taxar desocupação ficar 12,3 semana o junho o pesquisar nacional amostrar domicílio contínuo covid pnad covid divulgar hoje ibge instituto brasileiro geografia e estatístico o ficar abaixar 12,4 registrar semana anterior acima semana maio 10,5 semana referência pesquisar ibge 11,8 milhão desempregar semana o junho o contingente subir 38,1 milhão levar contar o população ocupar procurar trabalhar forçar trabalhar gostar trabalhar 26,4 milhão forçar gostar trabalhar 17,3 milhão deixar buscar empregar causar pandemia covid-19 trabalhar localidade o população ocupar ficar milhão pessoa semana o junho estável comparação semana anterior indicar haver perda empregar total ocupar 13,3 11,1 milhão trabalhador afastar causar medir isolamento social relacionar covid-19 abaixar 19,8 semana maio sinalizar retornar trabalhador o atividades ocupar 8,7 milhão 12,5 total exercer atividades remotamente trabalhar casar contingente manter estável o início pnad covid
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: dia falar o caneta eventualmente tirar governar integrante virar estrelo o presidente jair bolsonaro convidar o ex-ministro e deputar federal osmar terra almoçar palácio planalto encontrar hoje fonte acontecer levar sondagem o possibilidade terra assumir o ministério saudar luiz henrique mandetta o assunto principal interlocutor o respeitar cloroquina o tratamento coronavírus auxiliar apesar desgastar o presidente e mandetta riscar o presidente tirar o ministrar saudar n demitir apanhar duvidar fonte terra vestir palácio planalto cabeça alinhar o o presidente hoje artigo publicar folhar o ex-ministro ressalvar quarentenar e sugerir flexibilização defender o presidente
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o diretor-presidente agência nacional vigilância sanitário anvisa antonio barrir torre precisar mudar o comportamento social razão pandemia coronavírus o inimigo o chance o melhor chance n guerra passar obrigatoriamente mudança comportamento social o vacinar o vitória alcançar declarar o reunião o anvisa definir pedir emergencial vacinar brasil começar 10h pedir analisar reunião durar cercar horar o instituto butantan parceria o farmacêutico chinês sinovac e o fundação oswaldo cruz fiocruz parceiro consórcio astrazeneca oxford entrar requerimento autorização caráter emergencial vacinar
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: ação bem-humorada alertar idoso perigo sair s ruir dever pandemia coronavírus e pedir ficar casar durante período ganhar ruir goiânia o caminhão catar vir chamar começar o vestir ruir e avenida capital goiano morador vídeo veículo viralizaram rede social o carro som pedir bem-humorada idoso — principal riscar covid-19 — casar casar contrário levar o caminhão catar vir vir levar acima recolher vir o caminhão catar vir trecho áudio morador setor bueno o advogar yasminne freitas oliveira flagrar o veículo passar ruir janela apartamento vídeo carro passar manhã e postar rede social horar o registrar visualização apartamento manhã voltar 9h30 ouvir o carro som achar o áudio engraçar e postar twitter amigo mundo achar inusitado e começar o repostar e o vídeo viralizou contar
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: brasília reuters faltar dinheiro o vacinação população o coronavírus e o prioridade absoluto ministério economia hoje o secretário político econômica pastar adolfo sachsida live promovido jota sachsida haver recurso necessário querer tomar o vacinar e o principal n deixar o população seguro haver disponibilização imunizante
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: comitê independente formar facebook fato solicitar o restauração post usuário frança o facebook informar admitir errar crer publicação rede social
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: menino ano chamar vitoriar arrecadar doação distrito federal escrever cartar pedir ajudar o fome família recentemente pandemia coronavírus o pai d perder o empregar e o render familiar diminuir acordar o tv globo irmão e ajudar irmão escrever o cartar linha folhar caderno passar fome escrever o garoto mamãe e papar sair pedir o comer ruir ajudar o reportagem emissor perguntar tirar o idear escrever o polícia o menino cabeça querer policial falar ajudar sic abraçar alimento e item necessidade básico criança ganhar brinquedo o texto chegar o batalhão polícia militar df alimento casar cama dormir irmão fraldar vestir relatar o coronel jorge barreto pm globo
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o paciente recuperar covid-19 doença provocar coronavírus chegar o 3.656 caso confirmar o cidade rir janeiro o balançar painel rir covid-19 prefeitura divulgar n quarta-feira 1.775 pessoa conseguir recuperar doença capital fluminense pessoa morrer função covid-19 o redar único saudar sus capital haver 1.133 pessoa hospitalizar causar doença leito unidade terapia intensivo uti bairro concentrar o infectar coronavírus barrir tijuca copacabana tijuca leblon botafogo campar ipanema bangu flamengo e jacarepaguá país o morte razão pandemia coronavírus chegar o 2.906 conformar balançar recente divulgar ministério saudar caso confirmar subir 45.757 o índice letalidade ficar 6,4 o ministrar saudar nelson teich confirmar 25,3 pessoa conseguir recuperar doença
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: “ covid19 fonte universidade hamburgo o morte mundo 2.360 coronavírus 69.602 resfriar comum 140.584 malária 153.696 suicídio 193,479 acidente carro ônibus 240.950 morte hiv 358.471 álcool 716,498 fumar 1.177.141 câncer achar corona perigoso o objetivo campanha mídia resolver o guerra comercial o chino e unir reduzir mercar financeiro preparar o cenário mercar financeiro fusão e aquisição vender título tesourar eua cobrir o déficit fiscal n … pânico criar empresar farmacêutico vender produto desinfetante máscara remédio etc pânico e matar medo desnecessário postar equilibrar feed notícia postagens causar medo e pânico 82.000 pessoa doente coronavírus 77.000 chino população 1,1 bilião pessoa significar chino visitar o chino recentemente eliminar preocupação contrair coronavírus motivar pânico caso mild caso moderar caso crítico o significar obter o vírus provável voce recuperar “ o sars ” o sars apresentar taxar mortalidade o covid-19 apresentar taxar mortalidade d observar idade d morrer vírus o taxar mortalidade pessoa ano 0,2 significar ano e morar chino – provável ganhar loteria chance 45.000.000 piorar dia fevereiro pessoa chino morrer coronavírus dia 26.283 pessoa morrer câncer 24.641 pessoa morrer doença cardíaco 4.300 pessoa morrer diabete o suicídio levar vidar o vírus mosquito matar 2.740 pessoa dia humano matar 1.300 companheiro humano dia e cobrar matar pessoa dia tubarão matar pessoa ano tomar multi vitaminar e diário apoiar imunológico higiene adequar e vivo medo compartilhar parar o pânico ”
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: pessoa trabalhar legalmente indústria sexo japão acesso o o pacote ajudar econômica governar informar o ministrar saudar e trabalhar kazunobu kato entrevisto coletiva o medir sinalizar mudança planar original excluir restaurante e bar indústria entretenimento adulto o governar fornecer subsídio 8.330 iene r$ dia empresar permitir funcionário tirar féria cuidar criança escola o planar original haver criticar discriminação ocupacional membro oposição governar
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: impactar crise econômica causar coronavírus o arrecadação federal cair 29,59 junho comparação o ano passar informar o ministério economia n quinta-feira o tombar descontar o inflação período o resultar ficar r$ 86,25 bilião o o ano seguir o tendência registrar maio 32,92 e abril 28,95 comparação ... ler íntegro folhar
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: paciente internar uti unidade terapia intensivo covid-19 o dobrar taxar mortalidade hospital público comparação privar projeto utis brasileiro produzir amib associação medicinar intensivo brasileiro informação colhido 13.941 paciente tratar o coronavírus o taxar mortalidade unidade privar ficar 19,5 hospital público chegar o 38,5 — o índice referente o sair uti 1º março o maio período registrar filar esperar terapia intensivo indicador levantamento ajudar o entender o motivar mortalidade alto pessoa o doença o principal d referente o demorar acesso o serviço aumentar o gravidade paciente chegar tratamento leito terapia intensivo serviço público marcador indicar o gravidade paciente o o chegar uti escorar sofa critério pontuação base avaliação diverso parâmetro paciente casar utis público escorar médio paciente chegar ficar 5,7 quase o dobrar 3,1 paciente redar privar casar d índice gravar
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: ['arquivos', 'notícias', 'página', '2', '68', 'mpv', 'skip', 'to', 'content', 'home', 'últimas', 'editoriais', 'artigos', 'estudos', 'fact', 'checking', 'análises', 'vídeos', 'associese', 'estados', 'abaixo', 'assinado', 'carta', 'brasil', '2021', 'movimento', 'legislação', 'vida', 'excelentíssimos', 'membros', 'poder', 'judiciário', 'ministério', 'público', 'médicos', 'jornada', 'manifestos', 'manifestos', 'regionais', 'sugestões', 'imed', 'suporte', 'contato', 'help', 'desk', 'categoria', 'notícias', 'estudos', 'notícias', 'covid19', 'novo', 'estudo', 'confirma', 'eficácia', 'negativa', 'vacinas', 'após', 'seis', 'meses', 'redação', 'mpv', '16', 'agosto', '2024', 'após', 'período', 'vacinados', 'quase', 'dobro', 'chance', 'pegar', 'covid19', 'comparado', 'vacinados', 'revelam', 'dados', 'destaque1', 'moderna', 'pfizer', 'vacina', 'read', 'more', 'geral', 'notícias', '124ª', 'live', 'comunica', 'mpv', 'debate', 'nova', 'cara', 'cfm', 'pós', 'eleições', 'último', 'dia', '07', 'agosto', 'terçafeira', '13', '20h30', 'josé', 'aparecido', 'ribeiro', '10', 'agosto', '2024', 'eleição', 'cfm', 'objeto', 'questionamentos', 'jornalistas', 'ativistas', 'neste', 'caso', 'valeu', 'inclusive', 'duvidar', 'modelo', 'eleitoral', 'dr', 'antônio', 'jordão', 'neto', 'presidente', 'médicos', 'vida', 'dr', 'jandir', 'loureiro', 'dr', 'lincoln', 'ferreira', 'dr', 'osmar', 'terra', 'eleição', 'conselheiros', 'cfm', '2024', 'imprensa', 'ativista', 'read', 'more', 'notícias', 'estudo', 'revela', 'queda', 'dramática', 'confiança', 'médicos', 'hospitais', 'durante', 'pandemia', 'covid19', 'redação', 'mpv', '8', 'agosto', '2024', 'confiança', 'médicos', 'hospitais', 'diminuiu', '715', '401', 'pessoas', 'sabem', 'enganadas', 'nunca', 'confiarão', 'cegamente', 'sistema', 'médico', 'novamente', 'destaque1', 'medicos', 'vida', 'read', 'more', 'geral', 'notícias', 'live', 'especial', 'mpv', 'ampa', 'excepcionalmente', 'terçafeira', '6', '20h30', 'perseguição', 'contra', 'cristianismo', 'parte', 'ala', 'ativista', 'judiciário', 'combatendo', 'cultura', 'bíblica', 'josé', 'aparecido', 'ribeiro', '3', 'agosto', '2024', 'ativismo', 'judicial', 'contra', 'fé', 'cristã', 'velado', 'caminha', 'passos', 'largos', 'explicitamente', 'aliança', 'medicna', 'pedagogia', 'antroposofica', 'ativismo', 'judicial', 'combate', 'fé', 'cristá', 'dra', 'ana', 'cristina', 'lemos', 'malheiros', 'professor', 'jeanmarie', 'lambert', 'read', 'more', 'navegação', 'posts', '1', '2', '3', '68', 'recomendado', 'covid19', 'estudo', 'falso', 'atacava', 'hidroxicloroquina', 'virou', 'manchete', 'brasil', 'todo', 'retirado', 'literatura', 'científica', 'estudo', 'contra', 'hidroxicloroquina', 'reverberado', 'imprensa', 'retratado', '3º', 'congresso', 'mundial', 'médicos', 'vida', 'parceria', 'flccc', 'alliance', 'paulo', 'live', 'comunica', 'mpv', 'am', 'pa', 'convidam', 'etapa', 'falando', 'globalismo', 'origens', 'sustentação', 'professor', 'jeanmarie', 'lambert', 'quartafeira', '21', '20h30', 'mitos', 'verdades', 'sobre', 'febre', 'oropouche', 'dr', 'edimilson', 'migowiski', 'dra', 'gelse', 'campos', '125ª', 'live', 'comunica', 'médicos', 'vida', 'terçafeira', '20', '20h30', 'menu', 'home', 'últimas', 'editoriais', 'artigos', 'vídeos', 'associese', 'redes', 'sociais', 'telegram', 'gettr', 'twitter', 'rumble', 'inscrevase', 'newsletter', 'artigos', 'importantes', 'caixa', 'entrada', 'newsletter', 'humano', 'deixe', 'campo', 'branco', 'inscrever', 'mpv', 'todos', 'direitos', 'reservados', 'cnpj', '19548229000193']
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: circular rede social vídeo homem apresentar caderneta vacinação cachorro adesivo vacinar vanguard htlp 5/ cv-l destinar prevenção coronavírus canino vídeo o homem vírus gente cão imune o vírus cachorro imunizar falar fabricar vacinar poupar vírus antigo alexandre merlo gerente técnico e pesquisar aplicar animar companhia zoetis fabricante vacinar mencionar vídeo explicar o produto destinar o humano o o coronavírus o coronavírus vacinar coronavírus haver haver década e provocar cão quadrar gastrointestinal principalmente diarreia s vômito coronavírus cão haver pertencer família coronavírus coronavírus o sars coronavírus acometer humano vacinar servir prevenir o coronavirose canino vacinar servir tratar pessoa infecção coronavírus
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: o brasil isolamento social bocar o o longo ano passar presidente repúblico aliar coronavírus e excitar negacionistas o irar s ruir defeso autogolpe quarentenar totalmente obedecido resultar onda longo conectar refrescar pessoa e o economia consequentemente o auxílio emergencial continuar necessário o presidente senado rodrigar pacheco dem-mg afirmar corretamente o benefício assunto sobrevivência trabalhador e condicionar o ajuste fiscal haver defender o ministrar economia o saudar contar país importante o evitar o fome massa curtir o aprovação medir fiscal congresso jair messias silêncio torcer o voltar benefício o ajudar o estancar o sangria popularidade afirmar prorrogar e programar audiência popular comandar josé luiz datena jair messias toscar burro
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: morador flórido unir conseguir empregar durante o pandemia covid-19 ficar maridar mary daniel começar o lavar prato residência assistir steve internar alzheimer e o clínico proibir visitar evitar o contágio coronavírus redar social o norte-americana celebrar o empregar e o possibilidade abraçar o maridar novamente cem dia afastar criar virtual familiar e cuidador paciente o doença compartilhar história isolamento começar o trabalhar mary passar teste garantir representar riscar interno morar residência assistir haver ano e o isolamento pesar decisão mary começar o trabalhar visitar o maridar diariamente precisar parar – março – o clínico fechar proteger interno infecção coronavírus
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o cancelamento voo causar pandemia covid-19 o aeroporto vilnius capital lituânia transformar cinema drive-in estacionamento avião abrir espaçar carro e telão o criação cinema drive-in aeroporto o alternativo encontrar evitar o cancelamento festival internacional cinema vilnius sala cinema cidade fechar dever o o coronavírus e o aeroporto vaziar cancelamento voo organizador virar o oportunidade manter o festival pandemia o festival internacional cinema vilnius e o lithuanian airports unir criar o cinema drive-in mundo montar pistar aeroporto o aerocinema facilitar o cumprimentar regrar distanciamento social e o tela báltico prédio andar haver ruim n drive-in o projeto chamar aerocinema the journey begins aerocinema o jornada comedir o exibição filmar parasito vencedor oscar d ano o cinema drive-in funcionar durante o maio
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: eis o o publicação conter o foto menino
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: o cidadão acesso o trajetória sus vacinar tomar atendimento exame internação medicamento armazenar redar nacional rnds o ministério saudar publicar edição d o portar nº 1.434 instituir o programar conectar sus compor redar nacional saudar rnds e informatização atenção saudar desenvolver departamento informático sus datasus o conectar sus novembro o projeto-piloto alagoa estratégia possibilitar o o cidadão o trajetória sus vacinar tomar atendimento realizar exame internação medicamento estabelecimento saudar organizar o rnds ampliar o país o resultar melhor e organizar ofertar serviço saudar público o redar nacional saudar rnds plataforma permitir o prontuário eletrônico saudar e aplicativo conectar e trocar informação formato digital saudar indivíduo aprovação determinar população objetivando o aprimoramento promoção cuidar integrar saudar espera-se rnds informação saudar circular profissional saudar envolvido n casar seguro e rastreável proporcionar precisão diagnóstico e consequentemente acarretar resolutividade e continuidade cuidar o redar contribuir redução custo e desperdício serviço saudar
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: afirmação deputar federal bibo nunes live facebook defender o ivermectina o coronavírus o político basear estudar satoshi omura vencedor nobel medicinar comprovar o eficácia medicamentar
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: subir o caso confirmar covid-19 brasil — o total caso suspeito doença causar coronavírus país passar suspeito caso covid-19 registrar rir janeiro o boletim divulgar n secretariar saudar — balançar governar federal divulgar n contabilizar registro rir o secretário vigilância saudar ministério saudar wanderson oliveira afirmar esperar caso confirmar oliveira o ministério aguardar o conclusão teste o coronavírus confirmar caso monitoramento — caso o suspeito descartar atualmente haver caso confirmar e distrito federal alagoa bahia minar gerar espírito santo rir janeiro e paulo
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o msc cruzeiro decidir estender o suspensão embarque frota maio atuais circunstância o mundo enfrentar decorrência emergência saudar global causar covid-19 o companhia haver anunciar anteriormente o paralisação temporário navio o mundo abril governo o mundo reforçar medir saudar e segurança o proteger população locar e conter o disseminação vírus o decisão visar refletir e apoiar o eficácia esforço o anúncio o companhia fornecer o agente viagem e hóspede reservar viagem afetadas o possibilidade reagendar reservar cruzeiro o controlo pandemia medir oferecido companhia d o oportunidade reaver o total pagar féria cancelar crédito adicional benefício cruzeiro futurar o o
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: dia março danilo limar sair brasil rumar tailândia esposo e cunhar curtir féria pessoa imaginar o coronavírus mudar plano dúvida viagem decidir manter o programação caso brasil e país asiático prever o surtir vir apesar decisão danilo deixar informar atualizações propagação vírus vir acompanhar notícia locar pego surpreso contar danilo registrar o regrar distanciamento elevador imagem danilo limar
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: vacinar o covid-19 testar junho brasil o drogar desenvolvido universidade oxford e o farmacêutico astrazeneca
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: dia março o usp universidade paulo anunciar o formação redar laboratório reforçar o diagnóstico molecular coronavírus sars-cov-2 dezena e-mails chegar o o coordenador iniciativo o médico roger chammas professor fm faculdade medicinar enviar pesquisador disposto o ajudar voluntariamente força-tarefa emocionante receber mensagem aluno doutorar estagiário pós-doc e professorar usp e universidade colocar disposição auxiliar ampliação teste laboratorial paulo chammas dia o oms organização mundial saudar haver recomendar o testagem massa tentativo conter o avançar explosivo epidemiar mundo usp instituição paulista o universidade estadual campino unicamp e o instituto butantan mobilizar laboratório estratégia governar suprir o crescente demandar análise caso suspeito tarefar vir desempenhar unicamente instituto adolfo lutz principal órgão vigilância epidemiológico paulo cientista consciente necessidade unir esforço enfrentar crise afirmar chammas chamar o atenção o senso solidariedade e auxílio mútuo instalar acadêmico o confirmação casar coronavírus brasil fevereiro
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o imagem surgir rede social quinzena fevereiro e mostrar supor trecho história lançar personagem gaulês astérix participar corrido biga personagem chamar coronavírus
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: washington afp unir registrar n terça-feira 1º 2.500 morte coronavírus horar o alto abril acordar universidade johns hopkins o país registrar caso covid-19 dia o relatório o o diário morte superar 2.597 d terça-feira abril auge onda infecção pandemia plenamente controlar
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o justiçar paulo determinar operador plano saudar garantir atendimento e tratamento necessário o paciente suspeito confirmação covid-19 independente cumprimentar prazo carência dia o decisão proferir n caráter liminar prever o descumprimento decisão implicar multar r$ paciente vir o o cobertura recusar acordar o lei plano saudar horar assinatura contratar o segurar algum emergência urgência receber tratamento continuar precisar respeitar dia carência internação empresar o resolução 13/1998 saudar suplementar consu limitar o internação n caso o horar decisão o juiz fábio souza pimenta 32ª varar cível tribunal justiçar paulo abusivo o negativo cobertura planar saudar o paciente suspeito efetivamente portador vírus razão carência contratual caso distinção considerar urgente o defensoria público paulo responsável ação relatar coluna semana passar limitação horar criar obrigação desproporcional consumidor extremo vulnerabilidade o órgão defender regulamentação administrativo sobrepor o o código defeso consumidor e o recusar plano saudar garantir o continuidade custear internação emergência caso confirmar suspeito covid-19 haver recomendação médico causar dano irreparável o o indivíduo e sociedade
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o imagem homem vestir astronauta passear praia ipanema zonar sul rir janeiro viralizou internet pandemia coronavírus o roupar o símbolo nasa e criar passeio cidade e praia idoso e problema crônico pulmonar o contador aposentar tércio galdino limar ano decidir confeccionar o macacão e o capacete caminhar segurança ruir rir e reduzir o riscar contágio coronavírus e convencer o esposo o corretor imóvel alicea limar ano o aderir o o look dia preocupação pagar mico o alicea apreensivo o gente chegar praia vermelho urca dever o pessoa família criança o focar gente atração total mundo virar olhar pessoa começar o elogiar e coração explodir bater acelerar pessoal falar pôr original deixar aliviar contar tercio casal passear rir o proteção o covid-19 roupar astronauta imagem arquivar pessoal
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: beneficiário bolsar família o receber o pagamento auxílio emergencial r$ r$ 1,2 casar mulher chefe família aprovar congresso nacional acordar o ministério cidadania receber transferência render governar federal cidadão base governar o objetivo pastar viabilizar o pagamento folhar comedir o pago abril o beneficiário casar haver hábil radar o possibilidade rodar folhar suplementar agilizar o liberação beneficiário receber o ajudar casar o auxílio emergencial substituir o bolsar temporariamente o programar hoje milhão família trabalhador pretender pleitear o auxílio emergencial dirigir o agência bancário lotérica centrar referência assistência social cras n o governar definir o cadastrar o ministério esperar definir amanhã o solução tecnológico cadastrar trabalhador informar hoje invisível administração público base o gargalo operacionalização pagamento auxílio emergencial
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: “ prometer vacinar covid gravar desserviço o o público avaliar presidente merck … “ o pressa vacinar meramente financeiro liberar o carnaval mentir criminosamente o brasileiro ” kenneth carleton frazier presidente e ceo principal produtor vacinar mundo o gigante farmacêutico merck ”
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: vídeo mostrar profissional saudar frente o hospital virar costa veículo oficiar entrar prédio protestar bombado rede social mensagem circular juntar imagem tratar comitiva prefeito paulo brunir cova o vídeo gravar paulo bruxelas capital bélgica ocasião profissional saudar protestar o presença primeira-ministra belga sophie wilmès hospital saint-pierre o programar tv belga o unir registrar o protestar sábado acordar o reportagem cercar cem enfermeiro médico e auxiliar profissional limpeza e setor administrativo e bombeiro participar atar diverso veículo jornalístico mundo repercutir imagem e o notícia o inglês the guardian
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: calçar confortável pé bolsar ombro e o celular punho registrar melhorar o casal paulo roberto silvar e soraia abreu alves desbravar hoje corredor barrashopping zonar oeste rir reaberto o quarentenar sorriso esconder o animação reabertura shopping antecipar dia hoje decretar prefeito marcelo crivella republicano riscar o coronavírus o horar o isolamento social flexibilizar voltar o sair casar vulnerável doença passar motivar selfie toar casar haver ano o shopping o casal frequentar epidemiar vir passear precisar arejar viver afirmar silvar comemorar o fato o shopping cheio o diminuir risco contaminação continuar virar realizar hoje quarentenar completar
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o escalar pandemia covid-19 paulo levar o ministério público o questionar o governar estadual e o prefeitura capital critério estabelecido adotarem lockdown total ofício enviar o o secretário estadual saudar jean gorinchteyn o o secretário municipal saudar edson aparecer e o o prefeito brunir cova psdb o promotor dora martin strilicherk pedir esclarecimento iniciativo implementar monitorar o cumprimentar restrição imposto planar combater o o coronavírus o promotor demonstrar preocupação o contágio transportar público e questionar o gestão joão doria psdb o articulação entrar secretariar saudar e segurança público polícia militar fiscalização medir restrição s atividades essencial e lazer
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: centena médico estrangeiro e refugiar inscrever ajudar combater o o coronavírus inglaterra o saudar país aplicar testar inglês o seleção filippo grandi alto-comissário agência onu refugiar acnur elogiar o determinação altruísta médico responder o o chamar refugiar competência profissional comprovar pronto intervir e contribuir permitir o supervisão profissional saudar certificar d mostrar solidariedade e retribuir s comunidade abrigar afirmar grandi porta-voz saudar inglês o o jornal the guardian ficar grato centena manifestação interessar função suportar médico
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: enfermeiro arriscar o empregar e o vidar e denúncia cabulosa “ matar mundo ” “ cadê direito humano ” … o corajoso enfermeiro entubar pessoa e baixar o oxigênio o técnico o ordem mundial impor hospital e vc parente assassinar hospital curar e matar o redução populacional ordem mundial trabalhar d jeito hospital o visão dono hospital diretores médico e enfermeiro matar pessoa nome macabro agendar o agendar ordem mundial infelizmente d desdobramento astral aparecer alguém pra falar verdade lembrar técnico modus operandi hospital e upar território nacional e motivar liberar o tratamento precoce(ivermectina zincar e hidroxicloroquina morte o culpar presidente repúblico tá parabém o guerreiro luzir e o universo proteção necessário o divulgar massa coragem
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: o agência aviação onu alertar n quarta-feira fadigar piloto e licença expirar companhia aéreo preparar voar novamente restrição viagem imposto conter o propagação coronavírus suspenso alertar organização internacional aviação civil oaci considerar particular o fechamento estabelecimento incluir simulador voar e clínico levar o contratempo significativo o treinamento tripulação e controlador tráfego aéreo e certificar médico licença e aprovação inviável o icao defender autoridade aviação civil revisar pedir isenção o regulamento casar o casar e incluir avaliação risco segurança e proposto mitigar risco adicionar orientação icao risco decorrente pandemia contido manual autoridade transportar aéreo
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: semana substituir luiz henrique mandetta ministrar saudar pandemia coronavírus nelson teich distante protagonismo assumir antecessor e criticar podcast clero timidez apresentar o o cargo difícil o população o jornalista diogo schelp faltar o o ministrar saudar governar jair bolsonaro demonstrar o firmeza o exigir o caso e morte covid-19 crescer brasil o protagonismo o presidente crise visto ministrar saudar n país e o casar timidez o casar atrapalhar precisar firmeza e o mostrar n semana cargo firmeza afirmar o jornalista disponível arquivar acima o 42:30 comentário diogo schelp demonstrar preocupação o aparentar conhecimento ministrar o o único saudar sus
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: dia o governar bolsonaro completar dia ministrar cair o nono ministrar o sair o início mandatar jair bolsonaro o pastar saudar — o pandemia matar quase pessoa brasil — e o período dia cargo nelson teich pedir demissão discordância o presidente o presidência repúblico e o ministério saudar travar batalhar político morte e contaminação coronavírus continuar o crescer rapidamente o país registrar caso confirmar e 14.817 morte covid-19 15.305 caso horar o diagnóstico único dia bater o recordar 13.944 caso registrar dia anterior o principal atrito o médico teich e bolsonaro o o cloroquina tratamento covid-19 doença causar coronavírus o presidente defender o medicamentar início doença e demitir ministrar anterior luiz henrique mandetta justamente o medicamentar cautela o repetir teich apesar nomear o justificativo alinhar o o discursar presidente entretanto o o falar o medicamentar discursar posse teich sinal caminhar sentir absoluto bolsonaro
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: ['brasil', 'alta', 'covid', 'onda', 'deve', 'durar', '6', 'semanas', 'veja', 'risco', 'nova', 'variante', 'proteger', 'saúde', 'g1', 'saúde', 'brasil', 'alta', 'covid', 'onda', 'deve', 'durar', '6', 'semanas', 'veja', 'risco', 'nova', 'variante', 'proteger', 'taxa', 'testes', 'positivos', 'doença', 'dobrou', 'tanto', 'relatório', 'abramed', 'quanto', 'instituto', 'todos', 'saúde', 'itps', 'alta', 'associada', 'éris', 'subvariante', 'ômicron', 'monitorada', 'oms', 'roberto', 'peixoto', 'júlia', 'putini', 'g1', '31082023', '03h30', 'atualizado', '31082023', 'testes', 'positivos', 'aumentaram', '63', 'começo', 'mês', '138', 'metade', 'agosto', 'laboratórios', 'clínicas', 'privadas', 'segundo', 'abramed', 'levantamento', 'itps', 'grandes', 'redes', 'laboratórios', 'hospitais', 'aponta', 'variação', 'parecida', '7', '153', 'circulação', 'éris', 'fatores', 'apontados', 'especialistas', 'apesar', 'transmissível', 'associada', 'casos', 'graves', 'vacinação', 'meio', 'eficaz', 'proteção', 'reforço', 'vacina', 'bivalente', 'tomado', '15', 'públicoalvo', 'atual', 'onda', 'covid19', 'deve', 'durar', '4', '6', 'semanas', 'segundo', 'alberto', 'chebabo', 'presidente', 'sociedade', 'brasileira', 'infectologia', 'saiba', 'riscos', 'nova', 'variante', 'covid', 'proteger', 'taxa', 'testes', 'positivos', 'covid19', 'aumentou', 'brasil', 'primeiras', 'semanas', 'agosto', 'segundo', 'dois', 'relatórios', 'independentes', 'divulgados', 'quartafeira', '30', 'alta', 'ambos', 'levantamentos', 'ordem', '7', 'pontos', 'percentuais', 'representa', 'dobro', 'pessoas', 'testaram', 'positivo', 'vírus', 'sarscov2', 'entenda', 'cenário', 'aumento', 'ocorre', 'diante', 'cenário', 'distinto', 'verificado', 'momentos', 'anteriores', 'pandemia', 'maioria', 'população', 'vacinada', 'menos', 'risco', 'casos', 'graves', 'variante', 'oms', 'monitora', 'aumento', 'circulação', 'éris', 'subvariante', 'ômicron', 'fatores', 'apontados', 'especialistas', 'aumento', 'casosgravidade', 'apesar', 'transmissível', 'éris', 'associada', 'casos', 'graves', 'mortes', 'oms', 'variante', 'interesse', 'grau', 'inferior', 'variantes', 'preocupação', 'vacinação', 'brasil', 'enfrenta', 'sazonalidade', 'casos', 'maioria', 'população', 'tendo', 'tomado', 'doses', 'básicas', 'vacina', 'reforço', 'vacina', 'bivalente', 'aplicado', '15', 'públicoalvogrupos', 'vulneráveis', 'pessoas', 'imunossuprimidas', 'baixa', 'imunidade', 'doenças', 'transplante', 'devem', 'redobrar', 'cuidado', 'aglomerações', 'sempre', 'manter', 'uso', 'máscarasduração', 'onda', 'avaliação', 'alberto', 'chebabo', 'presidente', 'sociedade', 'brasileira', 'infectologia', 'atual', 'onda', 'covid', 'deve', 'durar', '4', '6', 'semanas', '1', '1', 'imagens', 'microscópio', 'mostram', 'partículas', 'coronavírus', 'causam', 'covid19', 'retiradas', 'paciente', 'eua', 'foto', 'arquivoniaidrml', 'via', 'ap', 'imagens', 'microscópio', 'mostram', 'partículas', 'coronavírus', 'causam', 'covid19', 'retiradas', 'paciente', 'eua', 'foto', 'arquivoniaidrml', 'via', 'ap', 'levantamento', 'testes', 'positivos', 'aumento', 'casos', 'reportado', 'duas', 'entidades', 'levantamentos', 'associação', 'brasileira', 'medicina', 'diagnóstica', 'abramed', 'representa', 'laboratórios', 'clínicas', 'privadas', 'aumento', 'testes', 'positivos', '63', '29', 'julho', '4', 'agosto', '138', '12', '18', 'agosto', 'possivelmente', 'sim', 'existe', 'relação', 'nova', 'variante', 'demonstrou', 'transmissível', 'embora', 'traga', 'quadros', 'graves', 'pessoas', 'infectadas', 'afirma', 'wilson', 'shcolnik', 'presidente', 'conselho', 'administração', 'abramed', 'outra', 'fonte', 'instituto', 'todos', 'saúde', 'itps', 'analisa', 'dados', 'laboratórios', 'dasa', 'db', 'molecular', 'fleury', 'hospital', 'israelita', 'albert', 'einstein', 'hiae', 'hilab', 'hlagyn', 'sabin', 'aumento', 'testes', 'positivos', '7', '153', 'semanas', 'encerradas', '22', 'julho', '19', 'agosto', 'segundo', 'itps', 'percentuais', 'elevados', 'observados', 'faixas', 'etárias', '49' ...
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o texto acompanhar vídeo espalhar rede social e whatsapp fevereiro e pra voltar o aparecer parabenizar o presidente jair bolsonaro trazer o brasil tecnologia revolucionário tratamento câncer mamar
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: o ministério saudar informar dia janeiro o crítico estocar oxigênio hospital manaus dia o insumo acabar hospital capital amazonense acordar manifestação agu advocacia-geral união enviar o o stf supremo tribunal federal o ofício respostar o determinação ministrar ricardo lewandowski sexta-feira horar o o governar apresentar planar assistência o manaus manifestação o agu o governar informar empresar fornecedor e-mail dia o situação estoque e alterar o planar visitar equipar ministério o manaus incluir inspeção localidade armazenamento e manejar oxigênio hospitalar
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: dr adib jatene o infectologista país o presidente errar resfriado dr adib jatene autoridade infectologia brasil o mídia tbm ignorante deixar o politicagem quebrar o economia brasil.*vejam o pronunciamento dr adib jatene o infectologista brasil câmara deputar federar 25/03/2020 o dr adib jatene infectogista e meter o pau presidente imbecil
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: “ respirar repetidamente o ar expirar transformar dióxido carbono e sentir tonto ... contraproducente pessoa servir o público horar intoxicar ” indicar o texto compartilhar facebook 2,4 o dia maio alegação replicar twitter português e idioma espanhol inglês e francês enviar o o whatsapp afp checar verificar “ recomendável usá-lo alguém frente e importante lembrar levantá-lo o minuto continuar sentir saudável sic ” continuar o mensagem
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: publicação dia junho página facebook indicar o medicamento azitromicina ivermectina e nitazoxanida pessoa sintoma leve covid-19 o texto sugerir o recomendação profissional saudar citar nome função supor colapso saudar brasil e direcionada o querer arriscar o o hospital".essa recomendação contrariar o orientação amplo autoridade e entidade saudar haver estudo andamento o ação d medicamento o vírus causar o covid-19 o sars-cov-2 o eficácia d comprovar o d o orientação pessoa apresentar sintoma procurar assistência médico e automedicar
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: “ “ cotonetão ” testar covid … “ o “ obter amostrar ” o testar covid-19 chamar barreirar sangue-cerebral único camada célula proteger o cérebro meter pesar pesticida e substância tóxico geralmente mantido nutriente vital o oxigênio atingir o cérebro algum o barreirar hematoencefálica comprometido tornar “ barreirar hematoencefálica vazamento ” cérebro inflamar seguir permitir bactéria e toxina entrar cérebro e infectar o tecer cerebral o levar o inflamação e s morte sintoma longo e curtir prazo incluir autismo dda tdah doença cardíaco doença autoimunes câncer doença neurodegenerativas acidentar vascular cerebral dano fígado fadigar crônica resolver repousar hipóxia ansiedade humor distúrbio depressão e condição saudar mental esquizofrenia convulsão perda memória e declínio cognitivo resultar alzheimer demência fluxo sanguíneo insuficiente o cérebro atividade cerebral anormal ” testar e casar contaminação encrencar ”
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: ['monitoramento', 'dados', 'vacinação', 'ministério', 'saúde', 'ir', 'conteúdo', '1', 'ir', 'página', 'inicial', '2', 'ir', 'menu', 'navegação', '3', 'ir', 'busca', '4', 'ir', 'mapa', 'site', '5', 'atenção', 'navegador', 'pode', 'executar', 'javascript', 'alguns', 'recursos', 'podem', 'funcionar', 'corretamente', 'portal', 'govbr', 'acesso', 'rápido', 'acesso', 'rápido', 'órgãos', 'governo', 'acesso', 'informação', 'legislação', 'acessibilidade', 'pt', 'escolher', 'idioma', 'en', 'es', 'redefinir', 'cookies', 'mudar', 'modo', 'alto', 'contraste', 'abrir', 'menu', 'principal', 'navegação', 'ministério', 'saúde', 'termos', 'buscados', 'assinatura', 'enem', 'imposto', 'renda', 'mei', 'inss', 'termos', 'buscados', 'assinatura', 'enem', 'imposto', 'renda', 'assuntos', 'notícias', '2024', '2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', 'notícias', 'estados', 'acre', 'alagoas', 'amapá', 'amazonas', 'bahia', 'ceará', 'distrito', 'federal', 'espírito', 'santo', 'goiás', 'maranhão', 'mato', 'grosso', 'mato', 'grosso', 'sul', 'minas', 'gerais', 'pará', 'paraíba', 'paraná', 'pernambuco', 'piauí', 'rio', 'janeiro', 'rio', 'grande', 'norte', 'rio', 'grande', 'sul', 'rondônia', 'roraima', 'santa', 'catarina', 'paulo', 'sergipe', 'tocantins', 'saúde', 'z', 'b', 'c', 'd', 'f', 'g', 'h', 'i', 'l', 'm', 'p', 'r', 's', 't', 'u', 'v', 'z', 'brasil', 'saudável', 'balanço', '2023', 'covid19', 'yanomami', 'novo', 'pac', 'saúde', 'onda', 'calor', 'protocolos', 'clínicos', 'diretrizes', 'terapêuticas', 'pcdt', 'retomada', 'obras', 'saúde', 'saúde', 'brasil', 'saúde', 'ciência', 'vacinação', 'calendário', 'vacinação', 'calendário', 'técnico', 'nacional', 'vacinação', 'atividades', 'vacinação', 'alta', 'qualidade', 'distribuição', 'imunobiológicos', 'segurança', 'vacinas', 'vacinas', 'grupos', 'especiais', 'vacinação', 'viajantes', 'rede', 'frio', 'informes', 'técnicos', 'notas', 'técnicas', 'manuais', 'legislação', 'publicações', 'estratégia', 'vacinação', 'contra', 'influenza', 'região', 'norte', '2024', 'cobertura', 'vacinal', 'monitoramento', 'dados', 'vacinação', 'composição', 'organograma', 'secretaria', 'executiva', 'consultoria', 'jurídica', 'denasus', 'atenção', 'especializada', 'saúde', 'atenção', 'primária', 'ciência', 'tecnologia', 'saúde', 'vigilância', 'saúde', 'ambiente', 'trabalho', 'educação', 'saúde', 'saúde', 'indígena', 'saúde', 'digital', 'corregedoria', 'órgãos', 'colegiados', 'conselho', 'nacional', 'saúde', 'conselho', 'saúde', 'suplementar', 'consu', 'comissão', 'nacional', 'incorporação', 'tecnologias', 'sus', 'conitec', 'entidades', 'vinculadas', 'autarquias', 'fundações', 'públicas', 'empresas', 'públicas', 'acesso', 'informação', 'institucional', 'agenda', 'autoridades', 'ações', 'programas', 'carta', 'serviços', 'participação', 'social', 'audiências', 'públicas', 'consultas', 'públicas', 'chamamentos', 'públicos', 'conselhos', 'comitês', 'órgãos', 'colegiados', 'auditorias', 'convênios', 'transferências', 'receitas', 'despesas', 'licitações', 'contratos', 'licitações', 'aquisições', 'internacionais', 'medicamentos', 'iot', 'contratos', 'ascom', 'contratos', 'departamento', 'logística', 'saúde', 'dlog', 'plano', 'contratação', 'anual', 'requisições', 'anestésicos', 'sessões', 'públicas', 'contratos', 'superintendências', 'sems', 'contratos', 'bens', 'serviços', 'administrativos', 'saa', 'servidores', 'avaliação', 'desempenho', 'despesas', 'ações', 'desenvolvimento', 'pessoas', 'estágio', 'informações', 'classificadas', 'serviço', 'informação', 'cidadão', 'sic', 'relatório', 'monitoramento', 'lai', '2024', 'perguntas', 'frequentes', 'faq', 'corregedoria', 'dados', 'abertos', 'sei', 'banco', 'preços', 'concursos', 'seleções', 'gestão', 'sus', 'governança', 'pública', 'lei', 'geral', 'proteção', 'dados', 'pessoais', 'lgpd', 'transparência', 'prestação', 'contas', 'relatório', 'integrado', 'gestão', 'ministério', 'saúde', 'relatórios', 'gestão', 'secretaria', 'vigilância', 'saúde', 'relató ...
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[0]
# ...
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: pandemia coronavírus o itália piorar problema brasileiro confinar navio atracar roma março dia país morte mundo 19.899 o arquiteta tecnologia lígio cossina ano passageiro embarcação contrair covid-19 o resultar testar sair n domingo páscoa medo acontecer piorar e fugir controlo o gente pensar certar simplesmente surpreendido planejado o consulado o itamaraty e o empresar cruzeiro o conduzir abandonar e aprisionar lígio o navio casar brasileiro passageiro e tripulante parar roma rejeitar porto país esperar autorização voltar o o brasil haver reclamação o atuação serviço diplomático brasileiro itália e empresar proprietário navio o arquiteta tecnologia morar paulo acreditar contaminar durante esperar voltar casar postergar o repatriação contaminar comunicar período manhã haver testar positivar o covid horar noite e informar passo procedimento protocolo médico e o gente o navio e aguardar respostar serviço diplomático
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: doriana gastar o nãovachina r$ bilião vacinar paulo fechadoscombolsonaroate2026quê gastar r$ bilião o vacinar oxford vacinar o brasil … doriatrancaruamais#brunocovase parente diretor butantã#dimascovasnão o cofre público paulo e paulistano … encher o bolsar o dinheiroa vacinar oxford pra imunizar brasileiro custar bilião real o vacinar chino pra imunizar o sp custar bilião real
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: imagem circular rede social o dezembro e semana janeiro amplamente compartilhar whatsapp provar campanha vacinação o coronavírus enganação mundo
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: mensagem compartilhar haver dia o óbito registrar paulo decorrência covid-19 inflar e exame divulgar positivo verdade resultar negativo o coronavírus o o governar revisar o mensagem manhã abril “ o fraudar paulista morte resultar negativar o coronavírus exame considerar inadequado o análise amostrar prejudicar material coleta incorreta ... ” e completar acordar o secretariar exame classificar “ extrair ” haver dúvida análise e teste refeito trocar miúdo negativo inadequado extrair morto paulo
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: dia consecutivo o brasil recordar óbito confirmar oficialmente ministério saudar provocar covid-19 acordar boletim divulgar noite hoje morte registrar horar o país chegar o 8.536 vítima fatal coronavírus e o colocar ranking mundial ultrapassar o bélgica 8.339 morte o governar confirmar 10.381 caso doença hoje o total o brasil passar o ministério divulgar pessoa recuperar covid-19 e curar o ministrar saudar nelson teich afirmar hoje o diretriz e município durante o pandemia coronavírus pronto organizar o melhor maneiro divulgar o o público o projeto propor o prefeito e governador programar isolamento social anunciar abril o prefeito rir janeiro marcelo crivella anunciar o amanhã s 5h bloquear calçadão campar zonar oeste conter o pandemia coronavírus
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: ['uso', 'hidroxicloroquina', 'durante', 'pandemia', 'covid', 'causou', '17', 'mil', 'mortes', 'seis', 'países', 'diz', 'estudo', 'estadão', 'assinenotícias', 'editoriasopiniãoúltimaspolíticacoluna', 'estadãoblogs', 'colunaseconomiaagronegóciosestadão', 'rigovernançaindicadoresmídia', 'mktnegóciossua', 'carreirablogs', 'colunaspmereforma', 'tributáriaeinvestidorbrasilsão', 'pauloblogs', 'colunasinternacionalblogs', 'colunasculturaartescinemaestado', 'arteliteraturamodamúsicaquadrinhossériesteatro', 'dançatelevisãoblogs', 'colunasesportescampeonatosbasquetefuteboltênisufcvelocidadevôleiblogs', 'colunasprogramação', 'tvestadão', 'verificainfográficos', 'especiaissaúdeacervoagrociênciablogs', 'colunaseeducaçãojornal', 'carrolinkrecomendamobilidadepaladarsustentabilidadesoluções', 'ambientaistudo', 'sobrever', 'ouvirpodcaststv', 'estadãofotosrádio', 'eldoradoweb', 'storiesdia', 'diacruzadashoróscopoloteriasnewslettersquadrinhossudokuparceiroscapituinstituto', 'vencer', 'câncerjornal', 'uspmar', 'fimneo', 'mondoo', 'estado', 'artesos', 'educaçãoprodutosagência', 'estadobroadcast', 'políticoclassificadosestadão', 'blue', 'studioestradãoimóveisrecomendaestadão', 'rinotícias', 'editoriasopiniãoúltimaspolíticacoluna', 'estadãoblogs', 'colunaseconomiaagronegóciosestadão', 'rigovernançaindicadoresmídia', 'mktnegóciossua', 'carreirablogs', 'colunaspmereforma', 'tributáriaeinvestidorbrasilsão', 'pauloblogs', 'colunasinternacionalblogs', 'colunasculturaartescinemaestado', 'arteliteraturamodamúsicaquadrinhossériesteatro', 'dançatelevisãoblogs', 'colunasesportescampeonatosbasquetefuteboltênisufcvelocidadevôleiblogs', 'colunasprogramação', 'tvestadão', 'verificainfográficos', 'especiaissaúdeacervoagrociênciablogs', 'colunaseeducaçãojornal', 'carrolinkrecomendamobilidadepaladarsustentabilidadesoluções', 'ambientaistudo', 'sobrever', 'ouvirpodcaststv', 'estadãofotosrádio', 'eldoradoweb', 'storiesdia', 'diacruzadashoróscopoloteriasnewslettersquadrinhossudokuprodutosagência', 'estadobroadcast', 'políticoclassificadosestadão', 'blue', 'studioestradãoimóveisrecomendaestadão', 'riassine', 'estadãoentrarpublicidadenotíciaestadãosaúdeuso', 'hidroxicloroquina', 'durante', 'pandemia', 'covid', 'causou', '17', 'mil', 'mortes', 'seis', 'países', 'diz', 'estudobrasil', 'nações', 'estudadas', 'especialistas', 'dizem', 'acreditar', 'país', 'registrado', 'alto', 'número', 'óbitos', 'associados', 'medicamentopublicidadepor', 'fabiana', 'cambricoli05012024', '22h59atualização', '09012024', '11h22correção', '09012024', '11h22o', 'uso', 'hidroxicloroquina', 'hcq', 'pacientes', 'hospitalizados', 'durante', 'primeira', 'onda', 'pandemia', 'covid19', '2020', 'levou', 'morte', 'cerca', '17', 'mil', 'pessoas', 'seis', 'países', 'dados', 'analisados', 'segundo', 'estimativa', 'estudo', 'publicado', 'periódico', 'biomedicine', 'pharmacotherapy', 'nesta', 'semana', 'brasil', 'nações', 'estudadas', 'especialistas', 'ouvidos', 'estadão', 'dizem', 'acreditar', 'país', 'registrado', 'alto', 'número', 'óbitos', 'associados', 'uso', 'medicamento', 'leia', 'abaixo', 'publicidadeo', 'remédio', 'usado', 'forma', 'indiscriminada', 'vários', 'países', 'início', 'pandemia', 'suposta', 'eficácia', 'combate', 'coronavírus', 'chegou', 'promovido', 'políticos', 'expresidente', 'americano', 'donald', 'trump', 'então', 'presidente', 'jair', 'bolsonaro', 'após', 'estudos', 'clínicos', 'demonstrarem', 'ineficácia', 'droga', 'tratamento', 'covid', 'bolsonaro', 'outros', 'políticos', 'alguns', 'médicos', 'continuaram', 'promovendo', 'medicamento', 'postura', 'contrária', 'ciênciaa', 'pesquisa', 'buscou', 'estimar', 'número', 'mortes', 'associadas', 'uso', 'dessa', 'medicação', 'realizada', 'cientistas', 'franceses', 'fez', 'projeções', 'base', '44', 'estudos', 'internacionais', 'dados', 'frança', 'bélgica', 'espanha', 'turquia', 'itália', 'estados', 'unidos', 'considerados', 'cálculo', 'indicadores', 'taxa', 'mortalidade', 'hospitalar', 'covid', 'exposição', 'hidroxicloroquina', 'númer ...
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: “ ” carvativir ” gota milagroso o “ cloroquina ” ditador madurar combater o covid-19 “ onda ” vir … ” “ nicolas apresentar o carvativir o curar – gundo o covid ”
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: o ministrar saudar eduardo pazuello hoje durante o chegar milhão dose vacinar oxford astrazeneca aeroporto galeão rir o brasil preciso produção nacional atender o demandar doméstico dose importar início o o processar país preciso produção nacional o produção nacional fiocruz butantan e provavelmente empresar particular produção vacinar sputnik v negociar o produção massa o produção quantidade vacinação massa o objetivo ministério saudar afirmar pazuello rápido pronunciamento o ministrar citar o brasil o pontapé inicial o produção paulo coronavac imunizante desenvolver laboratório chinês sinovac parceria o instituto butantan encontrar dificuldade o importação insumo
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o modo o ensinar remoto aplicar n ano receber crítico especialista educação professorar e aluno problema planejamento ausência infraestrutura adequar e dificuldade acesso o equipamento e internet apesar percalço indicar o ferramenta digitar vir ficar instituto atuam educação desenvolver pesquisar o experiência — ocasionar pandemia coronavírus — deixar legar estudar instituto península realizar o julho e mear agostar mostrar professorar veem o tecnologia completamente importante processar aprendizagem aluno frutar fase pesquisar sentimento e percepção professorar brasileiro diferente estágio coronavírus brasil entrevistar 4.000 professorar o país e superior o o verificar fase maio e abril o percentual
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o governar espanha anunciar hoje o país voltar o registrar morte horar e semana decorrência covid-19 o doença provocar coronavírus refletem mudança mecanismo contabilidade ministério saudar anunciar segunda-feira indicar óbito registrar dia anterior o o boletim hoje o início pandemia ocorrer 27.119 falecimento território espanhol n quinta-feira o boletim ministério saudar registrar caso infecção coronavírus elevar o total 237.906
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: semana fevereiro inúmero vídeo surgir rede social mostrar brincadeira aparentemente inofensivo – acordar o texto acompanhar – mortal
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: versão autoridade saudar e mídia silenciar morte idoso tomar vacinar chinês canelar versão idoso receber picado covid-666 e morrer covid-666 o culpar vacinar entender amigo versão canelar rs idoso morrer o aplicação vacinar sabemos.versão idoso cidade canelar virar jacaré … mudar o terra desencarnados horar vacinar o vacinar butantan terra-dura-dura … o cabeça gente sério alguém postar “ crer fato tomar o vacinar chino
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: circular rede social mensagem o vacinar fernando ramalhar diretor hospital paraíba morrer vítima covid-19 o provar o ineficácia coronavac fato o médico fernando ramalhar morrer vítima covid-19 tomar o dosar vacinar o pessoa vacinar adquirir imunidade completar e proteção o covid-19 o dosar o médico infectologista fernando chagar comitê científico combater covid-19 prefeitura municipal joão pessoa afirmar acordar estudo feito durante teste o vacinar observar proteção oferecido depender aplicação dose
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[0]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: familiar esperar semana respostar o testar covid-19 história vítima diagnóstico oficial escassez e demorar resultar xeque estatístico morto gabriel martinez ano músico e publicitário morar rir janeiro rj o família problema saudar sábado morrer hospital particular certidão óbito constar sepse pulmonar — infecção pulmão sintoma e o surpreso o morte jovem levar o família e médico o desconfiar causar infecção coronavírus semana morte músico teste feito base material colhido d ficar pronto
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: ex-secretário-executivo ministério saudar joão gabbardo abril o brasil dificilmente chegar o morto covid-19 o declaração passar o circular rede social n sábado o brasil superar o trágico marcar brasil falar óbito acreditar chegar n trabalhar acontecer afirmar gabbardo época haver morto e 9.056 caso covid-19 país coordenador executivo centrar contingência o covid-19 paulo gabbardo justificar o previsão sair ministério saudar óbito afirmar referindo-se somar vítima abril o ex-ministro saudar luiz henrique mandetta dem demitir o ex-secretário o o estadão o análise feito comparação estatístico morto chino informação subnotificadas previsão alterar
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o comediante dave chappelle popular stand-up norte-americano receber diagnóstico positivar coronavírus o notícia confirmar representante humorista o o deadline chappelle assintomático isolar casar conter o proliferação vírus show o comediante austin texas eua cancelar causar diagnóstico assessorar chappelle realizar apresentação implementar medir proteção o coronavírus ohio junho o mini-turnê exigir cuidar e equipar testar covid-19 diariamente
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------
#
# Notícia: o o contrário apresentador canal youtube morte confirmar coronavírus entrar estatístico o resultar positivar testar
#
# 	DecisionTreeClassifier()	[0]
# 	RandomForestClassifier()	[0]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[0]
# 	Target	[0]
# -----------------------------------------------------
#
# Notícia: o rússia fornecer milhão dose vacinar sputnik v covid-19 o o méxico durante o presidente mexicano andrés manuel lópez obrador ligação telefônica n segunda-feira vladimir putin o promessa presidente russo marcar aumentar expressivo meter anterior 7,4 milhão dose março haver dúvida o capacidade rússia manter o produção lópez obrador conversar putin telefonar apesar anunciar domingo haver infectar covid-19 e tratar sintoma moderar
#
# 	DecisionTreeClassifier()	[1]
# 	RandomForestClassifier()	[1]
# 	LogisticRegression()	[1]
# 	SVC(C=77, gamma=0.01)	[1]
# 	Target	[1]
# -----------------------------------------------------

# %%
# Calcula score de cada método para df externo
target = segundo_df_filtrado['noticia_falsa'].tolist()

acc_dt_e = cross_val_score(modelo_ad, X, y, scoring='accuracy')
acc_rf_e = cross_val_score(modelo_rf, X, y, scoring='accuracy')
acc_lr_e = cross_val_score(modelo_lr, X, y, scoring='accuracy')
acc_svc_e = cross_val_score(modelo_svm, X, y, scoring='accuracy')

prec_dt_e = cross_val_score(modelo_ad, X, y, scoring='precision')
prec_rf_e = cross_val_score(modelo_rf, X, y, scoring='precision')
prec_lr_e = cross_val_score(modelo_lr, X, y, scoring='precision')
prec_svc_e = cross_val_score(modelo_svm, X, y, scoring='precision')

acc_dt_mean = acc_dt_e.mean()
acc_rf_mean = acc_rf_e.mean()
acc_lr_mean = acc_lr_e.mean()
acc_svc_mean = acc_svc_e.mean()

acc_dt_std = acc_dt_e.std()
acc_rf_std = acc_rf_e.std()
acc_lr_std = acc_lr_e.std()
acc_svc_std = acc_svc_e.std()

prec_dt_mean = prec_dt_e.mean()
prec_rf_mean = prec_rf_e.mean()
prec_lr_mean = prec_lr_e.mean()
prec_svc_mean = prec_svc_e.mean()

prec_dt_std = prec_dt_e.std()
prec_rf_std = prec_rf_e.std()
prec_lr_std = prec_lr_e.std()
prec_svc_std = prec_svc_e.std()

print('---- Decision Tree ----')
print(f'Acurácia: {acc_dt_mean:.3f} ± {acc_dt_std:.3f}\nPrecisão: {prec_dt_mean:.3f} ± {prec_dt_std:.3f}')
print()
print('---- Random Forest ----')
print(f'Acurácia: {acc_rf_mean:.3f} ± {acc_rf_std:.3f}\nPrecisão: {prec_rf_mean:.3f} ± {prec_rf_std:.3f}')
print()
print('---- Linear Regression ----')
print(f'Acurácia: {acc_lr_mean:.3f} ± {acc_lr_std:.3f}\nPrecisão: {prec_lr_mean:.3f} ± {acc_lr_std:.3f}')
print()
print('---- SVC ----')
print(f'Acurácia: {acc_svc_mean:.3f} ± {acc_svc_std:.3f}\nPrecisão: {prec_svc_mean:.3f} ± {acc_svc_std:.3f}')
print()
# Out:
# ---- Decision Tree ----
# Acurácia: 0.845 ± 0.010
# Precisão: 0.879 ± 0.020
#
# ---- Random Forest ----
# Acurácia: 0.932 ± 0.012
# Precisão: 0.924 ± 0.013
#
# ---- Linear Regression ----
# Acurácia: 0.921 ± 0.010
# Precisão: 0.898 ± 0.010
#
# ---- SVC ----
# Acurácia: 0.935 ± 0.009
# Precisão: 0.933 ± 0.009

# %%
# Definindo os dados
accuracy_list = [acc_dt_mean, acc_rf_mean, acc_lr_mean, acc_svc_mean]
precision_list = [prec_dt_mean, prec_rf_mean, prec_lr_mean, prec_svc_mean]
acc_std_list = [acc_dt_std, acc_rf_std, acc_lr_std, acc_svc_std]
prec_std_list = [prec_dt_std, prec_rf_std, prec_lr_std, prec_svc_std]
model_labels = ['Árvore de Decisão', 'Floresta Aleatória', 'Regressão Logística', 'SVM']
colors = ['red', 'orange', 'pink', 'purple']

# Posições das barras para os grupos
x = np.arange(2)  # Um ponto para "Precisão" e outro para "Acurácia"
width = 0.15      # Largura das barras

# Criando o gráfico sem zoom
fig, ax = plt.subplots(figsize=(8, 6))
for i in range(len(model_labels)):
    # Precisão
    ax.bar(x[0] + i * width - (1.5 * width), precision_list[i], width, label=model_labels[i], color=colors[i])
    ax.errorbar(x[0] + i * width - (1.5 * width), precision_list[i], yerr=prec_std_list[i], fmt='o', color='black', capsize=5)
    # Acurácia
    ax.bar(x[1] + i * width - (1.5 * width), accuracy_list[i], width, color=colors[i])
    ax.errorbar(x[1] + i * width - (1.5 * width), accuracy_list[i], yerr=acc_std_list[i], fmt='o', color='black', capsize=5)

# Configurando os rótulos e título
ax.set_xlabel('Métrica')
ax.set_ylabel('Valores')
ax.set_title('Precisão e Acurácia dos Modelos para o Corpo dos Textos (Sem Zoom)')
ax.set_xticks(x)
ax.set_xticklabels(['Precisão', 'Acurácia'])
ax.legend()

# Exibindo o gráfico sem zoom
plt.show()

# Criando o gráfico com zoom
fig, ax = plt.subplots(figsize=(8, 6))
for i in range(len(model_labels)):
    # Precisão
    ax.bar(x[0] + i * width - (1.5 * width), precision_list[i], width, label=model_labels[i], color=colors[i])
    ax.errorbar(x[0] + i * width - (1.5 * width), precision_list[i], yerr=prec_std_list[i], fmt='o', color='black', capsize=5)
    # Acurácia
    ax.bar(x[1] + i * width - (1.5 * width), accuracy_list[i], width, color=colors[i])
    ax.errorbar(x[1] + i * width - (1.5 * width), accuracy_list[i], yerr=acc_std_list[i], fmt='o', color='black', capsize=5)

# Configurando os rótulos e título
ax.set_xlabel('Métrica')
ax.set_ylabel('Valores')
ax.set_title('Precisão e Acurácia dos Modelos para o Corpo dos Textos (Com Zoom)')
ax.set_xticks(x)
ax.set_xticklabels(['Precisão', 'Acurácia'])
ax.legend()

# Definindo o limite do eixo y para dar o "zoom"
plt.ylim(0.75, 1)

# Exibindo o gráfico com zoom
plt.show()
